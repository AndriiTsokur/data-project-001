# %% [markdown]
# # Profitable App Profiles for the App Store and Google Play Markets
#
# Our aim in this project is to find mobile app profiles that are profitable for the App Store and Google Play markets. We're working as data analysts for a company that builds Android and iOS mobile apps, and our job is to enable our team of developers to make data-driven decisions with respect to the kind of apps they build.
#
# At our company, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. This means that our revenue for any given app is mostly influenced by the number of users that use our app. Our goal for this project is to analyze data to help our developers understand what kinds of apps are likely to attract more users.
#
# ## Opening and Exploring the Data
#
# As of September 2018, there were approximately 2 million iOS apps available on the App Store, and 2.1 million Android apps on Google Play.
#
# ![img](https://s3.amazonaws.com/dq-content/350/py1m8_statista.png)
#
# Source: [Statista](https://www.statista.com/statistics/276623/number-of-apps-available-in-leading-app-stores/)
#
# Collecting data for over four million apps requires a significant amount of time and money, so we'll try to analyze a sample of data instead. To avoid spending resources with collecting new data ourselves, we should first try to see whether we can find any relevant existing data at no cost. Luckily, these are two data sets that seem suitable for our purpose:
#
# * A [data set](https://www.kaggle.com/lava18/google-play-store-apps) containing data about approximately ten thousand Android apps from Google Play is available by [this link](https://dq-content.s3.amazonaws.com/350/googleplaystore.csv).
# * A [data set](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps) containing data about approximately seven thousand iOS apps from the App Store is available by [this link](https://dq-content.s3.amazonaws.com/350/AppleStore.csv).
#
# Let's start by opening the two data sets and then continue with exploring the data.

# %%
from csv import reader

### The App Store data set ###
opened_file = open('./AppleStore.csv')
read_file = reader(opened_file)
ios = list(read_file)
ios_header = ios[0]
ios_data = ios[1:]

### The Google Play data set ###
opened_file = open('./googleplaystore.csv')
read_file = reader(opened_file)
android = list(read_file)
android_header = android[0]
android_data = android[1:]

PLATFORM = ({
	'name': 'Android',
	'header': android_header,
	'data': android_data,
	'data_eng': [],
	'data_final': []
	},
	{
	'name': 'iOS',
	'header': ios_header,
	'data': ios_data,
	'data_eng': [],
	'data_final': []
})

def define_platform(platform):
	for item in filter(lambda system: platform.lower() in system['name'].lower(), PLATFORM):
		return item

# %% [markdown]
# To make it easier to explore the two data sets, we'll first write a function named `explore_data()` that we can use repeatedly to explore rows in a more readable way. We'll also add an option for our function to show the number of rows and columns for any data set.

# %%
def explore_data(platform = 'android', start_row = 0, end_row = -1, rows_and_columns = True):
	dataset = define_platform(platform)

	print('{:*<100}'.format('*** Chosen platform: '))
	print(dataset['name'], '\n')

	print('{:*<100}'.format('*** Data header: '))
	print(dataset['header'], '\n')
	
	print('{:*<100}'.format('*** Data: '))
	for row in dataset['data'][start_row:end_row]:
		print(row, '\n')

	if rows_and_columns:
		print('\n*** Number of rows: ', len(dataset['data']))
		print('*** Number of columns: ', len(dataset['data'][0]))


explore_data(platform='and', start_row=0, end_row=3)
# Out:
# *** Chosen platform: *******************************************************************************
# Android
#
# *** Data header: ***********************************************************************************
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
# *** Data: ******************************************************************************************
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# *** Number of rows:  10841
# *** Number of columns:  13

# %% [markdown]
# We see that the Google Play data set has 10841 apps and 13 columns. At a quick glance, the columns that might be useful for the purpose of our analysis are `'App'`, `'Category'`, `'Reviews'`, `'Installs'`, `'Type'`, `'Price'`, and `'Genres'`.
#
# Now let's take a look at the App Store data set.

# %%
explore_data(platform='ios', start_row=0, end_row=3)
# Out:
# *** Chosen platform: *******************************************************************************
# iOS
#
# *** Data header: ***********************************************************************************
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
# *** Data: ******************************************************************************************
# ['284882215', 'Facebook', '389879808', 'USD', '0.0', '2974676', '212', '3.5', '3.5', '95.0', '4+', 'Social Networking', '37', '1', '29', '1']
#
# ['389801252', 'Instagram', '113954816', 'USD', '0.0', '2161558', '1289', '4.5', '4.0', '10.23', '12+', 'Photo & Video', '37', '0', '29', '1']
#
# ['529479190', 'Clash of Clans', '116476928', 'USD', '0.0', '2130805', '579', '4.5', '4.5', '9.24.12', '9+', 'Games', '38', '5', '18', '1']
#
#
# *** Number of rows:  7197
# *** Number of columns:  16

# %% [markdown]
# We have 7197 iOS apps in this data set, and the columns that seem interesting are: `'track_name'`, `'currency'`, `'price'`, `'rating_count_tot'`, `'rating_count_ver'`, and `'prime_genre'`. Not all column names are self-explanatory in this case, but details about each column can be found in the data set [documentation](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home).
#
#
#
# ## Deleting Wrong Data
#
# The Google Play data set has a dedicated [discussion section](https://www.kaggle.com/lava18/google-play-store-apps/discussion), and we can see that [one of the discussions](https://www.kaggle.com/lava18/google-play-store-apps/discussion/66015) outlines an error for row 10472. Let's print this row and compare it against the header and another row that is correct.

# %%
print(android_data[10472])  # incorrect row
print('\n')
print(android_header)  # header
print('\n')
print(android_data[0])      # correct row
# Out:
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']
#
#
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']

# %% [markdown]
# The row 10472 corresponds to the app *Life Made WI-Fi Touchscreen Photo Frame*, and we can see that the rating is 19. This is clearly off because the maximum rating for a Google Play app is 5 (as mentioned in the [discussions section](https://www.kaggle.com/lava18/google-play-store-apps/discussion/66015), this problem is caused by a missing value in the `'Category'` column). As a consequence, we'll delete this row.

# %%
# Don't run this more than once without Restart the kernel
print(len(android_data))

del android_data[10472]

print(len(android_data))
print(android_data[10472])
# Out:
# 10841
# 10840
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %% [markdown]
# ## Deleting Duplicate Entries
#
# Now it's time to check the datasets for duplicate records for each application name:

# %%
duplicates = {'android': [], 'ios': []}

def find_duplicates(platform):
	platform_dict = define_platform(platform)
	data = platform_dict['data']
	
	if platform_dict['name'].lower() == 'ios':
		app_name_idx = 1
	else:
		app_name_idx = 0

	duplicates_list = []
	for app in data:
		app_name = app[app_name_idx]
		row_idx = 0
		app_duplicates = []
		for row in data:
			if app_name == row[app_name_idx]:
				app_duplicates.append({'app_name': app_name, 'row_idx': row_idx})
			row_idx += 1
		if len(app_duplicates) > 1 and app_duplicates not in duplicates_list:
			duplicates_list.append(app_duplicates)
	duplicates[platform_dict['name'].lower()] = duplicates_list
	print_duplicates(platform_dict)


def print_duplicates(platform_dict):
	duplicates_list = duplicates[platform_dict['name'].lower()]
	data = platform_dict['data']

	print(f'Found {len(duplicates_list)} duplicate apps in {platform_dict['name']} dataset (total entries - {len(data)}):\n')
	for app in duplicates_list:
		print(app)
		print(platform_dict['header'])
		idx = 0
		for item in app:
			print(data[app[idx]['row_idx']])
			idx += 1
		print('\n')


find_duplicates('and')
# Out:
# Found 798 duplicate apps in Android dataset (total entries - 10840):
#
# [{'app_name': 'Coloring book moana', 'row_idx': 1}, {'app_name': 'Coloring book moana', 'row_idx': 2033}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
# ['Coloring book moana', 'FAMILY', '3.9', '974', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# [{'app_name': 'Mcqueen Coloring pages', 'row_idx': 23}, {'app_name': 'Mcqueen Coloring pages', 'row_idx': 2111}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Mcqueen Coloring pages', 'ART_AND_DESIGN', 'NaN', '61', '7.0M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Action & Adventure', 'March 7, 2018', '1.0.0', '4.1 and up']
# ['Mcqueen Coloring pages', 'FAMILY', 'NaN', '65', '7.0M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Action & Adventure', 'March 7, 2018', '1.0.0', '4.1 and up']
#
#
# [{'app_name': 'UNICORN - Color By Number & Pixel Art Coloring', 'row_idx': 36}, {'app_name': 'UNICORN - Color By Number & Pixel Art Coloring', 'row_idx': 7027}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['UNICORN - Color By Number & Pixel Art Coloring', 'ART_AND_DESIGN', '4.7', '8145', '24M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'August 2, 2018', '1.0.9', '4.4 and up']
# ['UNICORN - Color By Number & Pixel Art Coloring', 'FAMILY', '4.7', '8264', '24M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity', 'August 2, 2018', '1.0.9', '4.4 and up']
#
#
# [{'app_name': 'Textgram - write on photos', 'row_idx': 42}, {'app_name': 'Textgram - write on photos', 'row_idx': 4241}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Textgram - write on photos', 'ART_AND_DESIGN', '4.4', '295221', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'July 30, 2018', 'Varies with device', 'Varies with device']
# ['Textgram - write on photos', 'ART_AND_DESIGN', '4.4', '295237', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'July 30, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Wattpad 📖 Free Books', 'row_idx': 139}, {'app_name': 'Wattpad 📖 Free Books', 'row_idx': 4715}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Wattpad 📖 Free Books', 'BOOKS_AND_REFERENCE', '4.6', '2914724', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'August 1, 2018', 'Varies with device', 'Varies with device']
# ['Wattpad 📖 Free Books', 'BOOKS_AND_REFERENCE', '4.6', '2915189', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'August 1, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Amazon Kindle', 'row_idx': 143}, {'app_name': 'Amazon Kindle', 'row_idx': 4083}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Amazon Kindle', 'BOOKS_AND_REFERENCE', '4.2', '814080', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'July 27, 2018', 'Varies with device', 'Varies with device']
# ['Amazon Kindle', 'BOOKS_AND_REFERENCE', '4.2', '814151', 'Varies with device', '100,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'July 27, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Dictionary - Merriam-Webster', 'row_idx': 145}, {'app_name': 'Dictionary - Merriam-Webster', 'row_idx': 9621}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Dictionary - Merriam-Webster', 'BOOKS_AND_REFERENCE', '4.5', '454060', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'May 18, 2018', 'Varies with device', 'Varies with device']
# ['Dictionary - Merriam-Webster', 'BOOKS_AND_REFERENCE', '4.5', '454412', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'May 18, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'NOOK: Read eBooks & Magazines', 'row_idx': 146}, {'app_name': 'NOOK: Read eBooks & Magazines', 'row_idx': 6497}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['NOOK: Read eBooks & Magazines', 'BOOKS_AND_REFERENCE', '4.5', '155446', 'Varies with device', '10,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'April 25, 2018', 'Varies with device', 'Varies with device']
# ['NOOK: Read eBooks & Magazines', 'BOOKS_AND_REFERENCE', '4.5', '155466', 'Varies with device', '10,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'April 25, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Oxford Dictionary of English : Free', 'row_idx': 155}, {'app_name': 'Oxford Dictionary of English : Free', 'row_idx': 9642}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Oxford Dictionary of English : Free', 'BOOKS_AND_REFERENCE', '4.1', '363934', '7.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'July 11, 2018', '9.1.363', '4.1 and up']
# ['Oxford Dictionary of English : Free', 'BOOKS_AND_REFERENCE', '4.1', '364452', '7.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'July 11, 2018', '9.1.363', '4.1 and up']
#
#
# [{'app_name': 'Spanish English Translator', 'row_idx': 157}, {'app_name': 'Spanish English Translator', 'row_idx': 9570}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Spanish English Translator', 'BOOKS_AND_REFERENCE', '4.2', '87873', 'Varies with device', '10,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'May 28, 2018', 'Varies with device', 'Varies with device']
# ['Spanish English Translator', 'BOOKS_AND_REFERENCE', '4.2', '87919', 'Varies with device', '10,000,000+', 'Free', '0', 'Teen', 'Books & Reference', 'May 28, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'NOOK App for NOOK Devices', 'row_idx': 162}, {'app_name': 'NOOK App for NOOK Devices', 'row_idx': 6509}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['NOOK App for NOOK Devices', 'BOOKS_AND_REFERENCE', '4.7', '19080', 'Varies with device', '500,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'April 25, 2018', 'Varies with device', 'Varies with device']
# ['NOOK App for NOOK Devices', 'BOOKS_AND_REFERENCE', '4.7', '19090', 'Varies with device', '500,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'April 25, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Ebook Reader', 'row_idx': 164}, {'app_name': 'Ebook Reader', 'row_idx': 4095}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Ebook Reader', 'BOOKS_AND_REFERENCE', '4.1', '85842', '37M', '5,000,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'June 25, 2018', '5.0.6', '4.0 and up']
# ['Ebook Reader', 'BOOKS_AND_REFERENCE', '4.1', '85842', '37M', '5,000,000+', 'Free', '0', 'Everyone', 'Books & Reference', 'June 25, 2018', '5.0.6', '4.0 and up']
#
#
# [{'app_name': 'English Dictionary - Offline', 'row_idx': 186}, {'app_name': 'English Dictionary - Offline', 'row_idx': 6296}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['English Dictionary - Offline', 'BOOKS_AND_REFERENCE', '4.4', '341157', '30M', '10,000,000+', 'Free', '0', 'Everyone 10+', 'Books & Reference', 'March 20, 2018', '3.9.1', '4.2 and up']
# ['English Dictionary - Offline', 'BOOKS_AND_REFERENCE', '4.4', '341234', '30M', '10,000,000+', 'Free', '0', 'Everyone 10+', 'Books & Reference', 'March 20, 2018', '3.9.1', '4.2 and up']
#
#
# [{'app_name': 'Docs To Go™ Free Office Suite', 'row_idx': 192}, {'app_name': 'Docs To Go™ Free Office Suite', 'row_idx': 292}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Docs To Go™ Free Office Suite', 'BUSINESS', '4.1', '217730', 'Varies with device', '50,000,000+', 'Free', '0', 'Everyone', 'Business', 'April 2, 2018', 'Varies with device', 'Varies with device']
# ['Docs To Go™ Free Office Suite', 'BUSINESS', '4.1', '217730', 'Varies with device', '50,000,000+', 'Free', '0', 'Everyone', 'Business', 'April 2, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Google My Business', 'row_idx': 193}, {'app_name': 'Google My Business', 'row_idx': 239}, {'app_name': 'Google My Business', 'row_idx': 268}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
# ['Google My Business', 'BUSINESS', '4.4', '70991', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 24, 2018', '2.19.0.204537701', '4.4 and up']
#
#
# [{'app_name': 'OfficeSuite : Free Office + PDF Editor', 'row_idx': 194}, {'app_name': 'OfficeSuite : Free Office + PDF Editor', 'row_idx': 293}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['OfficeSuite : Free Office + PDF Editor', 'BUSINESS', '4.3', '1002861', '35M', '100,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '9.7.14188', '4.1 and up']
# ['OfficeSuite : Free Office + PDF Editor', 'BUSINESS', '4.3', '1002859', '35M', '100,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '9.7.14188', '4.1 and up']
#
#
# [{'app_name': 'Curriculum vitae App CV Builder Free Resume Maker', 'row_idx': 197}, {'app_name': 'Curriculum vitae App CV Builder Free Resume Maker', 'row_idx': 7939}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Curriculum vitae App CV Builder Free Resume Maker', 'BUSINESS', '4.5', '4458', '3.9M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 8, 2018', '3.3', '4.1 and up']
# ['Curriculum vitae App CV Builder Free Resume Maker', 'BUSINESS', '4.5', '4571', '3.9M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 8, 2018', '3.3', '4.1 and up']
#
#
# [{'app_name': 'Facebook Pages Manager', 'row_idx': 201}, {'app_name': 'Facebook Pages Manager', 'row_idx': 10200}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Facebook Pages Manager', 'BUSINESS', '4.0', '1279184', 'Varies with device', '50,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['Facebook Pages Manager', 'BUSINESS', '4.0', '1279800', 'Varies with device', '50,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 6, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Box', 'row_idx': 204}, {'app_name': 'Box', 'row_idx': 236}, {'app_name': 'Box', 'row_idx': 265}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['Box', 'BUSINESS', '4.2', '159872', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Call Blocker', 'row_idx': 206}, {'app_name': 'Call Blocker', 'row_idx': 436}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Call Blocker', 'BUSINESS', '4.6', '188841', '3.2M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'June 21, 2018', '1.1.13', '4.0 and up']
# ['Call Blocker', 'COMMUNICATION', '4.1', '17529', '10M', '1,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 26, 2018', '5.86', '4.0.3 and up']
#
#
# [{'app_name': 'ZOOM Cloud Meetings', 'row_idx': 213}, {'app_name': 'ZOOM Cloud Meetings', 'row_idx': 256}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['ZOOM Cloud Meetings', 'BUSINESS', '4.4', '31614', '37M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '4.1.28165.0716', '4.0 and up']
# ['ZOOM Cloud Meetings', 'BUSINESS', '4.4', '31614', '37M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '4.1.28165.0716', '4.0 and up']
#
#
# [{'app_name': 'Facebook Ads Manager', 'row_idx': 215}, {'app_name': 'Facebook Ads Manager', 'row_idx': 10203}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Facebook Ads Manager', 'BUSINESS', '4.1', '19023', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 1, 2018', '99.0.0.35.75', '4.1 and up']
# ['Facebook Ads Manager', 'BUSINESS', '4.1', '19051', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 1, 2018', '99.0.0.35.75', '4.1 and up']
#
#
# [{'app_name': 'Quick PDF Scanner + OCR FREE', 'row_idx': 222}, {'app_name': 'Quick PDF Scanner + OCR FREE', 'row_idx': 229}, {'app_name': 'Quick PDF Scanner + OCR FREE', 'row_idx': 285}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80805', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
# ['Quick PDF Scanner + OCR FREE', 'BUSINESS', '4.2', '80804', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 26, 2018', 'Varies with device', '4.0.3 and up']
#
#
# [{'app_name': 'SignEasy | Sign and Fill PDF and other Documents', 'row_idx': 228}, {'app_name': 'SignEasy | Sign and Fill PDF and other Documents', 'row_idx': 284}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['SignEasy | Sign and Fill PDF and other Documents', 'BUSINESS', '4.3', '8978', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 25, 2018', 'Varies with device', 'Varies with device']
# ['SignEasy | Sign and Fill PDF and other Documents', 'BUSINESS', '4.3', '8978', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 25, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Genius Scan - PDF Scanner', 'row_idx': 230}, {'app_name': 'Genius Scan - PDF Scanner', 'row_idx': 286}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Genius Scan - PDF Scanner', 'BUSINESS', '4.4', '42492', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 11, 2018', 'Varies with device', 'Varies with device']
# ['Genius Scan - PDF Scanner', 'BUSINESS', '4.4', '42492', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 11, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Tiny Scanner - PDF Scanner App', 'row_idx': 231}, {'app_name': 'Tiny Scanner - PDF Scanner App', 'row_idx': 287}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Tiny Scanner - PDF Scanner App', 'BUSINESS', '4.7', '286897', '39M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'May 30, 2017', '1.2.6', '3.0 and up']
# ['Tiny Scanner - PDF Scanner App', 'BUSINESS', '4.7', '286897', '39M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'May 30, 2017', '1.2.6', '3.0 and up']
#
#
# [{'app_name': 'Fast Scanner : Free PDF Scan', 'row_idx': 232}, {'app_name': 'Fast Scanner : Free PDF Scan', 'row_idx': 288}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Fast Scanner : Free PDF Scan', 'BUSINESS', '4.5', '103755', '14M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 11, 2018', '3.9.2', '4.1 and up']
# ['Fast Scanner : Free PDF Scan', 'BUSINESS', '4.5', '103755', '14M', '10,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 11, 2018', '3.9.2', '4.1 and up']
#
#
# [{'app_name': 'Mobile Doc Scanner (MDScan) Lite', 'row_idx': 233}, {'app_name': 'Mobile Doc Scanner (MDScan) Lite', 'row_idx': 289}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Mobile Doc Scanner (MDScan) Lite', 'BUSINESS', '4.2', '46505', '19M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '3.4.49', '4.1 and up']
# ['Mobile Doc Scanner (MDScan) Lite', 'BUSINESS', '4.2', '46505', '19M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '3.4.49', '4.1 and up']
#
#
# [{'app_name': 'TurboScan: scan documents and receipts in PDF', 'row_idx': 234}, {'app_name': 'TurboScan: scan documents and receipts in PDF', 'row_idx': 290}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['TurboScan: scan documents and receipts in PDF', 'BUSINESS', '4.7', '11442', '6.8M', '100,000+', 'Paid', '$4.99', 'Everyone', 'Business', 'March 25, 2018', '1.5.2', '4.0 and up']
# ['TurboScan: scan documents and receipts in PDF', 'BUSINESS', '4.7', '11442', '6.8M', '100,000+', 'Paid', '$4.99', 'Everyone', 'Business', 'March 25, 2018', '1.5.2', '4.0 and up']
#
#
# [{'app_name': 'Tiny Scanner Pro: PDF Doc Scan', 'row_idx': 235}, {'app_name': 'Tiny Scanner Pro: PDF Doc Scan', 'row_idx': 291}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Tiny Scanner Pro: PDF Doc Scan', 'BUSINESS', '4.8', '10295', '39M', '100,000+', 'Paid', '$4.99', 'Everyone', 'Business', 'April 11, 2017', '3.4.6', '3.0 and up']
# ['Tiny Scanner Pro: PDF Doc Scan', 'BUSINESS', '4.8', '10295', '39M', '100,000+', 'Paid', '$4.99', 'Everyone', 'Business', 'April 11, 2017', '3.4.6', '3.0 and up']
#
#
# [{'app_name': 'Zenefits', 'row_idx': 237}, {'app_name': 'Zenefits', 'row_idx': 266}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Zenefits', 'BUSINESS', '4.2', '296', '14M', '50,000+', 'Free', '0', 'Everyone', 'Business', 'June 15, 2018', '3.2.1', '4.1 and up']
# ['Zenefits', 'BUSINESS', '4.2', '296', '14M', '50,000+', 'Free', '0', 'Everyone', 'Business', 'June 15, 2018', '3.2.1', '4.1 and up']
#
#
# [{'app_name': 'Google Ads', 'row_idx': 238}, {'app_name': 'Google Ads', 'row_idx': 267}, {'app_name': 'Google Ads', 'row_idx': 4979}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# ['Google Ads', 'BUSINESS', '4.3', '29313', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
# ['Google Ads', 'BUSINESS', '4.3', '29331', '20M', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', '1.12.0', '4.0.3 and up']
#
#
# [{'app_name': 'Slack', 'row_idx': 240}, {'app_name': 'Slack', 'row_idx': 269}, {'app_name': 'Slack', 'row_idx': 294}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Slack', 'BUSINESS', '4.4', '51507', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['Slack', 'BUSINESS', '4.4', '51507', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['Slack', 'BUSINESS', '4.4', '51510', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'FreshBooks Classic', 'row_idx': 241}, {'app_name': 'FreshBooks Classic', 'row_idx': 270}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['FreshBooks Classic', 'BUSINESS', '4.1', '1802', '26M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'April 18, 2018', '1.7.14', '4.2 and up']
# ['FreshBooks Classic', 'BUSINESS', '4.1', '1802', '26M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'April 18, 2018', '1.7.14', '4.2 and up']
#
#
# [{'app_name': 'Insightly CRM', 'row_idx': 242}, {'app_name': 'Insightly CRM', 'row_idx': 271}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Insightly CRM', 'BUSINESS', '3.8', '1383', '51M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 12, 2018', '3.24.1', '5.0 and up']
# ['Insightly CRM', 'BUSINESS', '3.8', '1383', '51M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 12, 2018', '3.24.1', '5.0 and up']
#
#
# [{'app_name': 'QuickBooks Accounting: Invoicing & Expenses', 'row_idx': 243}, {'app_name': 'QuickBooks Accounting: Invoicing & Expenses', 'row_idx': 272}, {'app_name': 'QuickBooks Accounting: Invoicing & Expenses', 'row_idx': 296}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['QuickBooks Accounting: Invoicing & Expenses', 'BUSINESS', '4.3', '23175', '41M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 13, 2018', '18.7', '4.1 and up']
# ['QuickBooks Accounting: Invoicing & Expenses', 'BUSINESS', '4.3', '23175', '41M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 13, 2018', '18.7', '4.1 and up']
# ['QuickBooks Accounting: Invoicing & Expenses', 'BUSINESS', '4.3', '23175', '41M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 13, 2018', '18.7', '4.1 and up']
#
#
# [{'app_name': 'HipChat - Chat Built for Teams', 'row_idx': 244}, {'app_name': 'HipChat - Chat Built for Teams', 'row_idx': 273}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['HipChat - Chat Built for Teams', 'BUSINESS', '3.8', '5868', '20M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 3, 2018', '3.19.005', '4.1 and up']
# ['HipChat - Chat Built for Teams', 'BUSINESS', '3.8', '5868', '20M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 3, 2018', '3.19.005', '4.1 and up']
#
#
# [{'app_name': 'Xero Accounting Software', 'row_idx': 245}, {'app_name': 'Xero Accounting Software', 'row_idx': 274}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Xero Accounting Software', 'BUSINESS', '3.5', '2111', 'Varies with device', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', 'Varies with device', 'Varies with device']
# ['Xero Accounting Software', 'BUSINESS', '3.5', '2111', 'Varies with device', '100,000+', 'Free', '0', 'Everyone', 'Business', 'July 30, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'MailChimp - Email, Marketing Automation', 'row_idx': 246}, {'app_name': 'MailChimp - Email, Marketing Automation', 'row_idx': 275}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['MailChimp - Email, Marketing Automation', 'BUSINESS', '4.1', '5448', '12M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 25, 2018', '4.9.1', '5.0 and up']
# ['MailChimp - Email, Marketing Automation', 'BUSINESS', '4.1', '5448', '12M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 25, 2018', '4.9.1', '5.0 and up']
#
#
# [{'app_name': 'Crew - Free Messaging and Scheduling', 'row_idx': 247}, {'app_name': 'Crew - Free Messaging and Scheduling', 'row_idx': 276}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Crew - Free Messaging and Scheduling', 'BUSINESS', '4.6', '4159', '48M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '6.1.2', '4.0.3 and up']
# ['Crew - Free Messaging and Scheduling', 'BUSINESS', '4.6', '4159', '48M', '500,000+', 'Free', '0', 'Everyone', 'Business', 'July 20, 2018', '6.1.2', '4.0.3 and up']
#
#
# [{'app_name': 'Asana: organize team projects', 'row_idx': 248}, {'app_name': 'Asana: organize team projects', 'row_idx': 277}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Asana: organize team projects', 'BUSINESS', '4.3', '20815', '10M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 26, 2018', '6.4.4', '5.0 and up']
# ['Asana: organize team projects', 'BUSINESS', '4.3', '20815', '10M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 26, 2018', '6.4.4', '5.0 and up']
#
#
# [{'app_name': 'Google Analytics', 'row_idx': 249}, {'app_name': 'Google Analytics', 'row_idx': 278}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Google Analytics', 'BUSINESS', '4.5', '78662', '22M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 13, 2018', '3.7.5', '4.4 and up']
# ['Google Analytics', 'BUSINESS', '4.5', '78662', '22M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'February 13, 2018', '3.7.5', '4.4 and up']
#
#
# [{'app_name': 'AdWords Express', 'row_idx': 250}, {'app_name': 'AdWords Express', 'row_idx': 279}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['AdWords Express', 'BUSINESS', '4.1', '7149', '11M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', '2.6.158', '4.0 and up']
# ['AdWords Express', 'BUSINESS', '4.1', '7149', '11M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 31, 2018', '2.6.158', '4.0 and up']
#
#
# [{'app_name': 'Accounting App - Zoho Books', 'row_idx': 251}, {'app_name': 'Accounting App - Zoho Books', 'row_idx': 280}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Accounting App - Zoho Books', 'BUSINESS', '4.5', '3079', '8.5M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '5.20.7', '4.1 and up']
# ['Accounting App - Zoho Books', 'BUSINESS', '4.5', '3079', '8.5M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '5.20.7', '4.1 and up']
#
#
# [{'app_name': 'Invoice & Time Tracking - Zoho', 'row_idx': 252}, {'app_name': 'Invoice & Time Tracking - Zoho', 'row_idx': 281}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Invoice & Time Tracking - Zoho', 'BUSINESS', '4.6', '5800', '8.6M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '5.20.7', '4.1 and up']
# ['Invoice & Time Tracking - Zoho', 'BUSINESS', '4.6', '5800', '8.6M', '100,000+', 'Free', '0', 'Everyone', 'Business', 'August 2, 2018', '5.20.7', '4.1 and up']
#
#
# [{'app_name': 'join.me - Simple Meetings', 'row_idx': 253}, {'app_name': 'join.me - Simple Meetings', 'row_idx': 261}, {'app_name': 'join.me - Simple Meetings', 'row_idx': 282}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up']
# ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up']
# ['join.me - Simple Meetings', 'BUSINESS', '4.0', '6989', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'July 16, 2018', '4.3.0.508', '4.4 and up']
#
#
# [{'app_name': 'Invoice 2go — Professional Invoices and Estimates', 'row_idx': 254}, {'app_name': 'Invoice 2go — Professional Invoices and Estimates', 'row_idx': 283}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Invoice 2go — Professional Invoices and Estimates', 'BUSINESS', '4.2', '16422', '28M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 1, 2018', '10.46.2', '4.1 and up']
# ['Invoice 2go — Professional Invoices and Estimates', 'BUSINESS', '4.2', '16422', '28M', '1,000,000+', 'Free', '0', 'Everyone', 'Business', 'August 1, 2018', '10.46.2', '4.1 and up']
#
#
# [{'app_name': 'LINE WEBTOON - Free Comics', 'row_idx': 297}, {'app_name': 'LINE WEBTOON - Free Comics', 'row_idx': 4724}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['LINE WEBTOON - Free Comics', 'COMICS', '4.5', '1013635', 'Varies with device', '10,000,000+', 'Free', '0', 'Teen', 'Comics', 'July 31, 2018', 'Varies with device', 'Varies with device']
# ['LINE WEBTOON - Free Comics', 'COMICS', '4.5', '1013944', 'Varies with device', '10,000,000+', 'Free', '0', 'Teen', 'Comics', 'July 31, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Daily Manga - Comic & Webtoon', 'row_idx': 312}, {'app_name': 'Daily Manga - Comic & Webtoon', 'row_idx': 6411}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Daily Manga - Comic & Webtoon', 'COMICS', '3.2', '1446', '7.1M', '100,000+', 'Free', '0', 'Mature 17+', 'Comics', 'May 18, 2018', '1.0', '4.0.3 and up']
# ['Daily Manga - Comic & Webtoon', 'COMICS', '3.2', '1462', '7.1M', '100,000+', 'Free', '0', 'Mature 17+', 'Comics', 'May 18, 2018', '1.0', '4.0.3 and up']
#
#
# [{'app_name': 'DC Comics', 'row_idx': 315}, {'app_name': 'DC Comics', 'row_idx': 8246}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['DC Comics', 'COMICS', '4.2', '25671', 'Varies with device', '1,000,000+', 'Free', '0', 'Teen', 'Comics', 'June 5, 2018', 'Varies with device', 'Varies with device']
# ['DC Comics', 'COMICS', '4.2', '25673', 'Varies with device', '1,000,000+', 'Free', '0', 'Teen', 'Comics', 'June 5, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Manga AZ - Manga Comic Reader', 'row_idx': 325}, {'app_name': 'Manga AZ - Manga Comic Reader', 'row_idx': 5905}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Manga AZ - Manga Comic Reader', 'COMICS', '3.3', '125', '4.7M', '5,000+', 'Free', '0', 'Teen', 'Comics', 'July 24, 2018', '1.0.4', '4.0.3 and up']
# ['Manga AZ - Manga Comic Reader', 'COMICS', '3.3', '126', '4.7M', '5,000+', 'Free', '0', 'Teen', 'Comics', 'July 24, 2018', '1.0.4', '4.0.3 and up']
#
#
# [{'app_name': 'Messenger – Text and Video Chat for Free', 'row_idx': 335}, {'app_name': 'Messenger – Text and Video Chat for Free', 'row_idx': 382}, {'app_name': 'Messenger – Text and Video Chat for Free', 'row_idx': 4104}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Messenger – Text and Video Chat for Free', 'COMMUNICATION', '4.0', '56642847', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 1, 2018', 'Varies with device', 'Varies with device']
# ['Messenger – Text and Video Chat for Free', 'COMMUNICATION', '4.0', '56646578', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 1, 2018', 'Varies with device', 'Varies with device']
# ['Messenger – Text and Video Chat for Free', 'COMMUNICATION', '4.0', '56642847', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 1, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'WhatsApp Messenger', 'row_idx': 336}, {'app_name': 'WhatsApp Messenger', 'row_idx': 381}, {'app_name': 'WhatsApp Messenger', 'row_idx': 3904}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['WhatsApp Messenger', 'COMMUNICATION', '4.4', '69119316', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['WhatsApp Messenger', 'COMMUNICATION', '4.4', '69119316', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['WhatsApp Messenger', 'COMMUNICATION', '4.4', '69109672', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 3, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Google Chrome: Fast & Secure', 'row_idx': 338}, {'app_name': 'Google Chrome: Fast & Secure', 'row_idx': 411}, {'app_name': 'Google Chrome: Fast & Secure', 'row_idx': 3996}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Google Chrome: Fast & Secure', 'COMMUNICATION', '4.3', '9642995', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 1, 2018', 'Varies with device', 'Varies with device']
# ['Google Chrome: Fast & Secure', 'COMMUNICATION', '4.3', '9643041', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 1, 2018', 'Varies with device', 'Varies with device']
# ['Google Chrome: Fast & Secure', 'COMMUNICATION', '4.3', '9642112', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 1, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Messenger Lite: Free Calls & Messages', 'row_idx': 339}, {'app_name': 'Messenger Lite: Free Calls & Messages', 'row_idx': 4106}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Messenger Lite: Free Calls & Messages', 'COMMUNICATION', '4.4', '1429035', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 25, 2018', '37.0.0.7.163', '2.3 and up']
# ['Messenger Lite: Free Calls & Messages', 'COMMUNICATION', '4.4', '1429038', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 25, 2018', '37.0.0.7.163', '2.3 and up']
#
#
# [{'app_name': 'Gmail', 'row_idx': 340}, {'app_name': 'Gmail', 'row_idx': 451}, {'app_name': 'Gmail', 'row_idx': 4096}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Gmail', 'COMMUNICATION', '4.3', '4604324', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['Gmail', 'COMMUNICATION', '4.3', '4604483', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['Gmail', 'COMMUNICATION', '4.3', '4604324', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 2, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Hangouts', 'row_idx': 341}, {'app_name': 'Hangouts', 'row_idx': 386}, {'app_name': 'Hangouts', 'row_idx': 464}, {'app_name': 'Hangouts', 'row_idx': 4153}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Hangouts', 'COMMUNICATION', '4.0', '3419249', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 21, 2018', 'Varies with device', 'Varies with device']
# ['Hangouts', 'COMMUNICATION', '4.0', '3419433', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 21, 2018', 'Varies with device', 'Varies with device']
# ['Hangouts', 'COMMUNICATION', '4.0', '3419513', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 21, 2018', 'Varies with device', 'Varies with device']
# ['Hangouts', 'COMMUNICATION', '4.0', '3419464', 'Varies with device', '1,000,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 21, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Viber Messenger', 'row_idx': 342}, {'app_name': 'Viber Messenger', 'row_idx': 385}, {'app_name': 'Viber Messenger', 'row_idx': 431}, {'app_name': 'Viber Messenger', 'row_idx': 467}, {'app_name': 'Viber Messenger', 'row_idx': 4676}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Viber Messenger', 'COMMUNICATION', '4.3', '11334799', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', 'Varies with device', 'Varies with device']
# ['Viber Messenger', 'COMMUNICATION', '4.3', '11334973', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', 'Varies with device', 'Varies with device']
# ['Viber Messenger', 'COMMUNICATION', '4.3', '11334973', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', 'Varies with device', 'Varies with device']
# ['Viber Messenger', 'COMMUNICATION', '4.3', '11335255', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', 'Varies with device', 'Varies with device']
# ['Viber Messenger', 'COMMUNICATION', '4.3', '11335481', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Firefox Browser fast & private', 'row_idx': 344}, {'app_name': 'Firefox Browser fast & private', 'row_idx': 412}, {'app_name': 'Firefox Browser fast & private', 'row_idx': 4074}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Firefox Browser fast & private', 'COMMUNICATION', '4.4', '3075028', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 10, 2018', 'Varies with device', 'Varies with device']
# ['Firefox Browser fast & private', 'COMMUNICATION', '4.4', '3075118', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 10, 2018', 'Varies with device', 'Varies with device']
# ['Firefox Browser fast & private', 'COMMUNICATION', '4.4', '3075096', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 10, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Yahoo Mail – Stay Organized', 'row_idx': 345}, {'app_name': 'Yahoo Mail – Stay Organized', 'row_idx': 452}, {'app_name': 'Yahoo Mail – Stay Organized', 'row_idx': 4800}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Yahoo Mail – Stay Organized', 'COMMUNICATION', '4.3', '4187998', '16M', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', '5.29.3', '4.4 and up']
# ['Yahoo Mail – Stay Organized', 'COMMUNICATION', '4.3', '4188142', '16M', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', '5.29.3', '4.4 and up']
# ['Yahoo Mail – Stay Organized', 'COMMUNICATION', '4.3', '4188345', '16M', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 18, 2018', '5.29.3', '4.4 and up']
#
#
# [{'app_name': 'imo beta free calls and text', 'row_idx': 346}, {'app_name': 'imo beta free calls and text', 'row_idx': 4123}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['imo beta free calls and text', 'COMMUNICATION', '4.3', '659395', '11M', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'June 7, 2018', '9.8.000000010492', '4.0 and up']
# ['imo beta free calls and text', 'COMMUNICATION', '4.3', '659395', '11M', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'June 7, 2018', '9.8.000000010492', '4.0 and up']
#
#
# [{'app_name': 'imo free video calls and chat', 'row_idx': 347}, {'app_name': 'imo free video calls and chat', 'row_idx': 383}, {'app_name': 'imo free video calls and chat', 'row_idx': 465}, {'app_name': 'imo free video calls and chat', 'row_idx': 4222}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['imo free video calls and chat', 'COMMUNICATION', '4.3', '4785892', '11M', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'June 8, 2018', '9.8.000000010501', '4.0 and up']
# ['imo free video calls and chat', 'COMMUNICATION', '4.3', '4785988', '11M', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'June 8, 2018', '9.8.000000010501', '4.0 and up']
# ['imo free video calls and chat', 'COMMUNICATION', '4.3', '4785988', '11M', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'June 8, 2018', '9.8.000000010501', '4.0 and up']
# ['imo free video calls and chat', 'COMMUNICATION', '4.3', '4785892', '11M', '500,000,000+', 'Free', '0', 'Everyone', 'Communication', 'June 8, 2018', '9.8.000000010501', '4.0 and up']
#
#
# [{'app_name': 'Opera Mini - fast web browser', 'row_idx': 351}, {'app_name': 'Opera Mini - fast web browser', 'row_idx': 417}, {'app_name': 'Opera Mini - fast web browser', 'row_idx': 4421}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Opera Mini - fast web browser', 'COMMUNICATION', '4.5', '5149854', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['Opera Mini - fast web browser', 'COMMUNICATION', '4.5', '5150471', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 19, 2018', 'Varies with device', 'Varies with device']
# ['Opera Mini - fast web browser', 'COMMUNICATION', '4.5', '5150801', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 19, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Opera Browser: Fast and Secure', 'row_idx': 356}, {'app_name': 'Opera Browser: Fast and Secure', 'row_idx': 415}, {'app_name': 'Opera Browser: Fast and Secure', 'row_idx': 4422}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Opera Browser: Fast and Secure', 'COMMUNICATION', '4.4', '2473509', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', '47.1.2249.129326', 'Varies with device']
# ['Opera Browser: Fast and Secure', 'COMMUNICATION', '4.4', '2473693', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', '47.1.2249.129326', 'Varies with device']
# ['Opera Browser: Fast and Secure', 'COMMUNICATION', '4.4', '2473795', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 31, 2018', '47.1.2249.129326', 'Varies with device']
#
#
# [{'app_name': 'Firefox Focus: The privacy browser', 'row_idx': 358}, {'app_name': 'Firefox Focus: The privacy browser', 'row_idx': 408}, {'app_name': 'Firefox Focus: The privacy browser', 'row_idx': 10719}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Firefox Focus: The privacy browser', 'COMMUNICATION', '4.4', '36880', '4.0M', '1,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 6, 2018', '5.2', '5.0 and up']
# ['Firefox Focus: The privacy browser', 'COMMUNICATION', '4.4', '36893', '4.0M', '1,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 6, 2018', '5.2', '5.0 and up']
# ['Firefox Focus: The privacy browser', 'COMMUNICATION', '4.4', '36981', '4.0M', '1,000,000+', 'Free', '0', 'Everyone', 'Communication', 'July 6, 2018', '5.2', '5.0 and up']
#
#
# [{'app_name': 'Google Voice', 'row_idx': 359}, {'app_name': 'Google Voice', 'row_idx': 394}, {'app_name': 'Google Voice', 'row_idx': 5594}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Google Voice', 'COMMUNICATION', '4.2', '171031', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Google Voice', 'COMMUNICATION', '4.2', '171031', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Google Voice', 'COMMUNICATION', '4.2', '171052', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Communication', 'August 3, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Chrome Dev', 'row_idx': 360}, {'app_name': 'Chrome Dev', 'row_idx': 7353}]
# ...
#
#
# [{'app_name': 'Topbuzz: Breaking News, Videos & Funny GIFs', 'row_idx': 3738}, {'app_name': 'Topbuzz: Breaking News, Videos & Funny GIFs', 'row_idx': 4588}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Topbuzz: Breaking News, Videos & Funny GIFs', 'NEWS_AND_MAGAZINES', '4.7', '175110', '25M', '10,000,000+', 'Free', '0', 'Mature 17+', 'News & Magazines', 'August 6, 2018', '6.7.3', '4.0 and up']
# ['Topbuzz: Breaking News, Videos & Funny GIFs', 'NEWS_AND_MAGAZINES', '4.7', '174827', '25M', '10,000,000+', 'Free', '0', 'Mature 17+', 'News & Magazines', 'August 4, 2018', '6.7.3', '4.0 and up']
#
#
# [{'app_name': 'Twitter', 'row_idx': 3739}, {'app_name': 'Twitter', 'row_idx': 3796}, {'app_name': 'Twitter', 'row_idx': 4115}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Twitter', 'NEWS_AND_MAGAZINES', '4.3', '11667403', 'Varies with device', '500,000,000+', 'Free', '0', 'Mature 17+', 'News & Magazines', 'August 6, 2018', 'Varies with device', 'Varies with device']
# ['Twitter', 'NEWS_AND_MAGAZINES', '4.3', '11667403', 'Varies with device', '500,000,000+', 'Free', '0', 'Mature 17+', 'News & Magazines', 'August 6, 2018', 'Varies with device', 'Varies with device']
# ['Twitter', 'NEWS_AND_MAGAZINES', '4.3', '11657972', 'Varies with device', '500,000,000+', 'Free', '0', 'Mature 17+', 'News & Magazines', 'July 30, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Flipboard: News For Our Time', 'row_idx': 3755}, {'app_name': 'Flipboard: News For Our Time', 'row_idx': 3767}, {'app_name': 'Flipboard: News For Our Time', 'row_idx': 3819}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Flipboard: News For Our Time', 'NEWS_AND_MAGAZINES', '4.4', '1284017', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Flipboard: News For Our Time', 'NEWS_AND_MAGAZINES', '4.4', '1284017', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 3, 2018', 'Varies with device', 'Varies with device']
# ['Flipboard: News For Our Time', 'NEWS_AND_MAGAZINES', '4.4', '1284018', 'Varies with device', '500,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 3, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Podcast App: Free & Offline Podcasts by Player FM', 'row_idx': 3760}, {'app_name': 'Podcast App: Free & Offline Podcasts by Player FM', 'row_idx': 10645}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Podcast App: Free & Offline Podcasts by Player FM', 'NEWS_AND_MAGAZINES', '4.6', '66384', '19M', '1,000,000+', 'Free', '0', 'Teen', 'News & Magazines', 'July 25, 2018', '4.1.0.72', '4.0 and up']
# ['Podcast App: Free & Offline Podcasts by Player FM', 'NEWS_AND_MAGAZINES', '4.6', '66407', '19M', '1,000,000+', 'Free', '0', 'Teen', 'News & Magazines', 'July 25, 2018', '4.1.0.72', '4.0 and up']
#
#
# [{'app_name': 'BuzzFeed: News, Tasty, Quizzes', 'row_idx': 3766}, {'app_name': 'BuzzFeed: News, Tasty, Quizzes', 'row_idx': 3818}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['BuzzFeed: News, Tasty, Quizzes', 'NEWS_AND_MAGAZINES', '4.3', '131028', '13M', '5,000,000+', 'Free', '0', 'Teen', 'News & Magazines', 'July 30, 2018', '5.38', '4.4 and up']
# ['BuzzFeed: News, Tasty, Quizzes', 'NEWS_AND_MAGAZINES', '4.3', '131028', '13M', '5,000,000+', 'Free', '0', 'Teen', 'News & Magazines', 'July 30, 2018', '5.38', '4.4 and up']
#
#
# [{'app_name': 'USA TODAY', 'row_idx': 3772}, {'app_name': 'USA TODAY', 'row_idx': 3790}, {'app_name': 'USA TODAY', 'row_idx': 3807}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['USA TODAY', 'NEWS_AND_MAGAZINES', '4.1', '49259', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['USA TODAY', 'NEWS_AND_MAGAZINES', '4.1', '49259', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['USA TODAY', 'NEWS_AND_MAGAZINES', '4.1', '49259', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'The Wall Street Journal: Business & Market News', 'row_idx': 3774}, {'app_name': 'The Wall Street Journal: Business & Market News', 'row_idx': 3809}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['The Wall Street Journal: Business & Market News', 'NEWS_AND_MAGAZINES', '4.1', '40975', '36M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', '4.4.2.19', '4.1 and up']
# ['The Wall Street Journal: Business & Market News', 'NEWS_AND_MAGAZINES', '4.1', '40975', '36M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', '4.4.2.19', '4.1 and up']
#
#
# [{'app_name': 'NYTimes - Latest News', 'row_idx': 3777}, {'app_name': 'NYTimes - Latest News', 'row_idx': 3814}, {'app_name': 'NYTimes - Latest News', 'row_idx': 5544}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['NYTimes - Latest News', 'NEWS_AND_MAGAZINES', '3.9', '63647', '23M', '10,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 1, 2018', '6.19.5', '4.4 and up']
# ['NYTimes - Latest News', 'NEWS_AND_MAGAZINES', '3.9', '63647', '23M', '10,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 1, 2018', '6.19.5', '4.4 and up']
# ['NYTimes - Latest News', 'NEWS_AND_MAGAZINES', '3.9', '63640', '23M', '10,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 1, 2018', '6.19.5', '4.4 and up']
#
#
# [{'app_name': 'NPR News', 'row_idx': 3782}, {'app_name': 'NPR News', 'row_idx': 3801}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['NPR News', 'NEWS_AND_MAGAZINES', '4.0', '24790', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'News & Magazines', 'July 20, 2018', 'Varies with device', 'Varies with device']
# ['NPR News', 'NEWS_AND_MAGAZINES', '4.0', '24790', 'Varies with device', '1,000,000+', 'Free', '0', 'Everyone', 'News & Magazines', 'July 20, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Reuters News', 'row_idx': 3783}, {'app_name': 'Reuters News', 'row_idx': 5474}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Reuters News', 'NEWS_AND_MAGAZINES', '4.3', '13169', '25M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'June 6, 2018', '3.4.4', '4.1 and up']
# ['Reuters News', 'NEWS_AND_MAGAZINES', '4.3', '13166', '25M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'June 6, 2018', '3.4.4', '4.1 and up']
#
#
# [{'app_name': 'Haystack TV: Local & World News - Free', 'row_idx': 3786}, {'app_name': 'Haystack TV: Local & World News - Free', 'row_idx': 3804}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Haystack TV: Local & World News - Free', 'NEWS_AND_MAGAZINES', '4.3', '3684', 'Varies with device', '100,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', 'Varies with device', 'Varies with device']
# ['Haystack TV: Local & World News - Free', 'NEWS_AND_MAGAZINES', '4.3', '3684', 'Varies with device', '100,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'August 2, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'ABC News - US & World News', 'row_idx': 3787}, {'app_name': 'ABC News - US & World News', 'row_idx': 3806}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['ABC News - US & World News', 'NEWS_AND_MAGAZINES', '4.0', '18976', '35M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'June 6, 2018', '3.19.11', '5.0 and up']
# ['ABC News - US & World News', 'NEWS_AND_MAGAZINES', '4.0', '18976', '35M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'June 6, 2018', '3.19.11', '5.0 and up']
#
#
# [{'app_name': 'NBC News', 'row_idx': 3788}, {'app_name': 'NBC News', 'row_idx': 3808}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['NBC News', 'NEWS_AND_MAGAZINES', '4.1', '63020', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'February 13, 2018', 'Varies with device', 'Varies with device']
# ['NBC News', 'NEWS_AND_MAGAZINES', '4.1', '63020', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'February 13, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'AP Mobile - Breaking News', 'row_idx': 3791}, {'app_name': 'AP Mobile - Breaking News', 'row_idx': 5448}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['AP Mobile - Breaking News', 'NEWS_AND_MAGAZINES', '4.5', '76677', '4.6M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'May 25, 2017', '4.4.3', '4.0 and up']
# ['AP Mobile - Breaking News', 'NEWS_AND_MAGAZINES', '4.5', '76616', '4.6M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'May 25, 2017', '4.4.3', '4.0 and up']
#
#
# [{'app_name': 'Newsroom: News Worth Sharing', 'row_idx': 3795}, {'app_name': 'Newsroom: News Worth Sharing', 'row_idx': 3815}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Newsroom: News Worth Sharing', 'NEWS_AND_MAGAZINES', '4.2', '201737', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'July 3, 2018', 'Varies with device', 'Varies with device']
# ['Newsroom: News Worth Sharing', 'NEWS_AND_MAGAZINES', '4.2', '201737', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'July 3, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'AC - Tips & News for Android™', 'row_idx': 3799}, {'app_name': 'AC - Tips & News for Android™', 'row_idx': 4928}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['AC - Tips & News for Android™', 'NEWS_AND_MAGAZINES', '4.2', '23292', '14M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'May 24, 2018', '3.1.12', '4.1 and up']
# ['AC - Tips & News for Android™', 'NEWS_AND_MAGAZINES', '4.2', '23291', '14M', '1,000,000+', 'Free', '0', 'Everyone 10+', 'News & Magazines', 'May 24, 2018', '3.1.12', '4.1 and up']
#
#
# [{'app_name': 'Waze - GPS, Maps, Traffic Alerts & Live Navigation', 'row_idx': 3820}, {'app_name': 'Waze - GPS, Maps, Traffic Alerts & Live Navigation', 'row_idx': 4717}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Waze - GPS, Maps, Traffic Alerts & Live Navigation', 'MAPS_AND_NAVIGATION', '4.6', '7232629', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'July 29, 2018', 'Varies with device', 'Varies with device']
# ['Waze - GPS, Maps, Traffic Alerts & Live Navigation', 'MAPS_AND_NAVIGATION', '4.6', '7231017', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'July 29, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Transit: Real-Time Transit App', 'row_idx': 3825}, {'app_name': 'Transit: Real-Time Transit App', 'row_idx': 5964}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Transit: Real-Time Transit App', 'MAPS_AND_NAVIGATION', '4.2', '43269', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'July 18, 2018', '4.4.7', 'Varies with device']
# ['Transit: Real-Time Transit App', 'MAPS_AND_NAVIGATION', '4.2', '43252', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'July 18, 2018', '4.4.7', 'Varies with device']
#
#
# [{'app_name': 'Mapy.cz - Cycling & Hiking offline maps', 'row_idx': 3826}, {'app_name': 'Mapy.cz - Cycling & Hiking offline maps', 'row_idx': 8138}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Mapy.cz - Cycling & Hiking offline maps', 'MAPS_AND_NAVIGATION', '4.5', '56443', '43M', '1,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'June 26, 2018', '6.2.0', '4.1 and up']
# ['Mapy.cz - Cycling & Hiking offline maps', 'MAPS_AND_NAVIGATION', '4.5', '56409', '43M', '1,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'June 26, 2018', '6.2.0', '4.1 and up']
#
#
# [{'app_name': 'Uber', 'row_idx': 3827}, {'app_name': 'Uber', 'row_idx': 4634}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Uber', 'MAPS_AND_NAVIGATION', '4.2', '4928420', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'August 6, 2018', 'Varies with device', 'Varies with device']
# ['Uber', 'MAPS_AND_NAVIGATION', '4.2', '4921866', 'Varies with device', '100,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'August 2, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Moovit: Bus Time & Train Time Live Info', 'row_idx': 3865}, {'app_name': 'Moovit: Bus Time & Train Time Live Info', 'row_idx': 5516}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Moovit: Bus Time & Train Time Live Info', 'MAPS_AND_NAVIGATION', '4.4', '617477', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'August 5, 2018', 'Varies with device', 'Varies with device']
# ['Moovit: Bus Time & Train Time Live Info', 'MAPS_AND_NAVIGATION', '4.4', '616742', 'Varies with device', '10,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'August 5, 2018', 'Varies with device', 'Varies with device']
#
#
# [{'app_name': 'Maps & GPS Navigation — OsmAnd', 'row_idx': 3869}, {'app_name': 'Maps & GPS Navigation — OsmAnd', 'row_idx': 6882}]
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
# ['Maps & GPS Navigation — OsmAnd', 'MAPS_AND_NAVIGATION', '4.2', '60838', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'August 6, 2018', 'Varies with device', 'Varies with device']
# ['Maps & GPS Navigation — OsmAnd', 'MAPS_AND_NAVIGATION', '4.2', '60820', 'Varies with device', '5,000,000+', 'Free', '0', 'Everyone', 'Maps & Navigation', 'August 1, 2018', 'Varies with device', 'Varies with device']

# %%
find_duplicates('ios')
# Out:
# Found 2 duplicate apps in iOS dataset (total entries - 7197):
#
# [{'app_name': 'Mannequin Challenge', 'row_idx': 2948}, {'app_name': 'Mannequin Challenge', 'row_idx': 4463}]
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# ['1173990889', 'Mannequin Challenge', '109705216', 'USD', '0.0', '668', '87', '3.0', '3.0', '1.4', '9+', 'Games', '37', '4', '1', '1']
# ['1178454060', 'Mannequin Challenge', '59572224', 'USD', '0.0', '105', '58', '4.0', '4.5', '1.0.1', '4+', 'Games', '38', '5', '1', '1']
#
#
# [{'app_name': 'VR Roller Coaster', 'row_idx': 4442}, {'app_name': 'VR Roller Coaster', 'row_idx': 4831}]
# ['id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
# ['952877179', 'VR Roller Coaster', '169523200', 'USD', '0.0', '107', '102', '3.5', '3.5', '2.0.0', '4+', 'Games', '37', '5', '1', '1']
# ['1089824278', 'VR Roller Coaster', '240964608', 'USD', '0.0', '67', '44', '3.5', '4.0', '0.81', '4+', 'Games', '38', '0', '1', '1']

# %% [markdown]
# Let's keep the entries with the maximum number of reviews for Android apps (column index 3) and the maximum number of ratings for iOS apps (column index 5). Other duplicate entries will be deleted.

# %%
def delete_extra_entries(platform):
	platform_dict = define_platform(platform)
	data = platform_dict['data']
	duplicates_list = duplicates[platform_dict['name'].lower()]
	initial_entries_number = len(data)

	if platform_dict['name'].lower() == 'ios':
		key_parameter_idx = 5
	else:
		key_parameter_idx = 3

	data_deletion_rows = []
	for app in duplicates_list:
		max_key_parameter = 0
		max_key_parameter_idx = None
		app_deletion_rows = []
		for item in app:
			key_parameter = int(data[item['row_idx']][key_parameter_idx])
			if key_parameter > max_key_parameter:
				max_key_parameter = key_parameter
				if max_key_parameter_idx:
					app_deletion_rows.append(max_key_parameter_idx)
				max_key_parameter_idx = item['row_idx']
			else:
				app_deletion_rows.append(item['row_idx'])
		data_deletion_rows += app_deletion_rows

	# Preparing for extra rows deletion
	data_deletion_rows.sort()
	data_deletion_rows.reverse()

	# Deleting extra rows
	for row_idx in data_deletion_rows:
		del data[row_idx]

	print(f'Removing duplicates with a smaller key parameter is complete for {platform_dict['name']}. {
	      initial_entries_number - len(data)} entries has been deleted. Remaining entries - {len(data)}.')

# Don't run this more than once without Restart the kernel
delete_extra_entries('and')
# Out:
# Removing duplicates with a smaller key parameter is complete for Android. 1184 entries has been deleted. Remaining entries - 9656.

# %%
# Don't run this more than once without Restart the kernel
delete_extra_entries('ios')
# Out:
# Removing duplicates with a smaller key parameter is complete for iOS. 2 entries has been deleted. Remaining entries - 7195.

# %% [markdown]
# To make sure all duplicates are removed, let's repeat their search for each platform:

# %%
find_duplicates('and')
# Out:
# Found 0 duplicate apps in Android dataset (total entries - 9656):

# %%
find_duplicates('ios')
# Out:
# Found 0 duplicate apps in iOS dataset (total entries - 7195):

# %% [markdown]
# ## Removing Non-English Apps
#
# We're not interested in keeping the apps which are not directed toward an English-speaking audience, so we'll remove them as well.
#
# Each character we use in a string has a corresponding number associated with it. For instance, the corresponding number for character 'a' is 97, character 'A' is 65, and character '爱' is 29,233. We can get the corresponding number of each character using the ord() built-in function.
#
# The numbers corresponding to the characters we commonly use in an English text are all in the range 0 to 127, according to the ASCII (American Standard Code for Information Interchange) system. Based on this number range, we can build a function that detects whether a character belongs to the set of common English characters or not. If the number is equal to or less than 127, then the character belongs to the set of common English characters.
#
# If an app name contains a character that is greater than 127, then it probably means that the app has a non-English name. To minimize the impact of data loss, we'll only remove an app if its name has more than three non-ASCII characters.
#
# We will copy all English-language applications into separate `PLATFORM['data_eng']` constant lists, which we will work with in the future.

# %%
def separate_non_english(platform):
	platform_dict = define_platform(platform)
	data = platform_dict['data']
	data_eng = platform_dict['data_eng'] = []

	if platform_dict['name'].lower() == 'ios':
		app_name_idx = 1
	else:
		app_name_idx = 0

	non_english_apps = []
	row_idx = 0
	for app in data:
		non_ascii = 0

		for char in app[app_name_idx]:
			if ord(char) > 127:
				non_ascii += 1

		if non_ascii > 3:
			non_english_apps.append({'name': app[app_name_idx], 'idx': row_idx})
		else:
			PLATFORM[app_name_idx]['data_eng'].append(PLATFORM[app_name_idx]['data'][row_idx])
		
		row_idx += 1

	print(f'Separated {len(non_english_apps)} non-English apps in {platform_dict['name']} dataset (total entries before - {len(data)}, after - {len(data_eng)}):\n')

	for app in non_english_apps:
		print(app)


separate_non_english('and')
# Out:
# Separated 45 non-English apps in Android dataset (total entries before - 9656, after - 9611):
#
# {'name': 'Flame - درب عقلك يوميا', 'idx': 529}
# {'name': 'သိင်္ Astrology - Min Thein Kha BayDin', 'idx': 1206}
# {'name': 'РИА Новости', 'idx': 2831}
# {'name': 'صور حرف H', 'idx': 3165}
# {'name': 'L.POINT - 엘포인트 [ 포인트, 멤버십, 적립, 사용, 모바일 카드, 쿠폰, 롯데]', 'idx': 3276}
# {'name': 'RMEduS - 음성인식을 활용한 R 프로그래밍 실습 시스템', 'idx': 3491}
# {'name': 'AJ렌터카 법인 카셰어링', 'idx': 4173}
# {'name': 'Al Quran Free - القرآن (Islam)', 'idx': 4252}
# {'name': '中国語 AQリスニング', 'idx': 4409}
# {'name': '日本AV历史', 'idx': 4583}
# {'name': 'Ay Yıldız Duvar Kağıtları', 'idx': 4723}
# {'name': 'বাংলা টিভি প্রো BD Bangla TV', 'idx': 4882}
# {'name': 'Cъновник BG', 'idx': 5038}
# {'name': 'CSCS BG (в български)', 'idx': 5073}
# {'name': '뽕티비 - 개인방송, 인터넷방송, BJ방송', 'idx': 5202}
# {'name': 'BL 女性向け恋愛ゲーム◆俺プリクロス', 'idx': 5274}
# {'name': 'SecondSecret ‐「恋を読む」BLノベルゲーム‐', 'idx': 5283}
# {'name': 'BL 女性向け恋愛ゲーム◆ごくメン', 'idx': 5285}
# {'name': 'あなカレ【BL】無料ゲーム', 'idx': 5286}
# {'name': '감성학원 BL 첫사랑', 'idx': 5288}
# {'name': 'BQ-መጽሐፍ ቅዱሳዊ ጥያቄዎች', 'idx': 5486}
# {'name': 'BS Calendar / Patro / पात्रो', 'idx': 5582}
# {'name': 'Vip视频免费看-BT磁力搜索', 'idx': 5658}
# {'name': 'Билеты ПДД CD 2019 PRO', 'idx': 6028}
# {'name': 'Offline Jízdní řády CG Transit', 'idx': 6134}
# {'name': 'Bonjour 2017 Abidjan CI ❤❤❤❤❤', 'idx': 6239}
# {'name': 'CK 初一 十五', 'idx': 6306}
# {'name': 'الفاتحون Conquerors', 'idx': 6588}
# {'name': 'DG ग्राम / Digital Gram Panchayat', 'idx': 7227}
# {'name': 'DM הפקות', 'idx': 7398}
# {'name': 'DW فارسی By dw-arab.com', 'idx': 7814}
# {'name': 'لعبة تقدر تربح DZ', 'idx': 7937}
# {'name': 'বাংলাflix', 'idx': 8020}
# {'name': 'RPG ブレイジング ソウルズ アクセレイト', 'idx': 8031}
# {'name': '英漢字典 EC Dictionary', 'idx': 8042}
# {'name': 'ECナビ×シュフー', 'idx': 8068}
# {'name': 'أحداث وحقائق | خبر عاجل في اخبار العالم', 'idx': 8128}
# {'name': 'EG SIM CARD (EGSIMCARD, 이지심카드)', 'idx': 8137}
# {'name': 'パーリーゲイツ公式通販｜EJ STYLE（イージェイスタイル）', 'idx': 8286}
# {'name': 'FAHREDDİN er-RÂZİ TEFSİRİ', 'idx': 8597}
# {'name': "I'm Rich/Eu sou Rico/أنا غني/我很有錢", 'idx': 8754}
# {'name': 'AÖF Ev İdaresi 1. Sınıf', 'idx': 8791}
# {'name': 'Ey Sey Storytime រឿងនិទានតាឥសី', 'idx': 8917}
# {'name': '哈哈姆特不EY', 'idx': 8928}
# {'name': 'FP Разбитый дисплей', 'idx': 9579}

# %%
separate_non_english('ios')
# Out:
# Separated 1014 non-English apps in iOS dataset (total entries before - 7195, after - 6181):
#
# {'name': '爱奇艺PPS -《欢乐颂2》电视剧热播', 'idx': 813}
# {'name': '聚力视频HD-人民的名义,跨界歌王全网热播', 'idx': 1193}
# {'name': '优酷视频', 'idx': 1427}
# {'name': '网易新闻 - 精选好内容，算出你的兴趣', 'idx': 1518}
# {'name': '淘宝 - 随时随地，想淘就淘', 'idx': 1595}
# {'name': '搜狐视频HD-欢乐颂2 全网首播', 'idx': 1603}
# {'name': '阴阳师-全区互通现世集结', 'idx': 1648}
# {'name': '百度贴吧-全球最大兴趣交友社区', 'idx': 1782}
# {'name': '百度网盘', 'idx': 1894}
# {'name': '爱奇艺HD -《欢乐颂2》电视剧热播', 'idx': 1905}
# {'name': '乐视视频HD-白鹿原,欢乐颂,奔跑吧全网热播', 'idx': 1916}
# {'name': '万年历-值得信赖的日历黄历查询工具', 'idx': 1941}
# {'name': '新浪新闻-阅读最新时事热门头条资讯视频', 'idx': 1956}
# {'name': '喜马拉雅FM（听书社区）电台有声小说相声英语', 'idx': 1996}
# {'name': '央视影音-海量央视内容高清直播', 'idx': 2010}
# {'name': '腾讯视频HD-楚乔传,明日之子6月全网首播', 'idx': 2018}
# {'name': '手机百度 - 百度一下你就得到', 'idx': 2048}
# {'name': '百度视频HD-高清电视剧、电影在线观看神器', 'idx': 2049}
# {'name': 'MOMO陌陌-开启视频社交,用直播分享生活', 'idx': 2095}
# {'name': 'QQ 浏览器-搜新闻、选小说漫画、看视频', 'idx': 2148}
# {'name': '同花顺-炒股、股票', 'idx': 2152}
# {'name': '聚力视频-蓝光电视剧电影在线热播', 'idx': 2190}
# {'name': '快看漫画', 'idx': 2203}
# {'name': '乐视视频-白鹿原,欢乐颂,奔跑吧全网热播', 'idx': 2233}
# {'name': '酷我音乐HD-无损在线播放', 'idx': 2372}
# {'name': '随手记（专业版）-好用的记账理财工具', 'idx': 2404}
# {'name': 'Dictionary ( قاموس عربي / انجليزي + ودجيت الترجمة)', 'idx': 2512}
# {'name': '滴滴出行', 'idx': 2520}
# {'name': '高德地图（精准专业的手机地图）', 'idx': 2563}
# {'name': '百度HD-极速安全浏览器', 'idx': 2574}
# {'name': '美丽说-潮流穿搭快人一步', 'idx': 2579}
# {'name': '百度地图-智能的手机导航，公交地铁出行必备', 'idx': 2592}
# {'name': 'Majiang Mahjong（单机+川麻+二人+武汉+国标）', 'idx': 2596}
# {'name': '土豆视频HD—高清影视综艺视频播放器', 'idx': 2607}
# {'name': '360手机卫士-超安全的来电防骚扰助手', 'idx': 2648}
# {'name': 'QQ浏览器HD-极速搜索浏览器', 'idx': 2655}
# {'name': '搜狗输入法-Sogou Keyboard', 'idx': 2713}
# {'name': '百度网盘 HD', 'idx': 2718}
# {'name': '大众点评-发现品质生活', 'idx': 2745}
# {'name': '讯飞输入法-智能语音输入和表情斗图神器', 'idx': 2772}
# {'name': '美柚 - 女生助手', 'idx': 2799}
# {'name': '爱奇艺 - 电视剧电影综艺娱乐视频播放器', 'idx': 2817}
# {'name': '搜狐视频-欢乐颂2 全网首播', 'idx': 2827}
# {'name': '百度地图HD', 'idx': 2829}
# {'name': 'QQ同步助手-新机一键换机必备工具', 'idx': 2859}
# {'name': 'QQ音乐-来这里“发现・音乐”', 'idx': 2861}
# {'name': '腾讯新闻-头条新闻热点资讯掌上阅读软件', 'idx': 2893}
# {'name': '土豆（短视频分享平台）', 'idx': 2943}
# {'name': '风行视频+ HD - 电影电视剧体育视频播放器', 'idx': 2971}
# {'name': '仙劍奇俠傳5 - 劍傲丹楓', 'idx': 2975}
# {'name': 'YY- 小全民手机直播交友软件', 'idx': 2998}
# {'name': '腾讯视频-欢乐颂2全网首播', 'idx': 3006}
# {'name': '中华万年历-2亿用户首选的日历软件', 'idx': 3031}
# {'name': '央视影音HD-海量央视内容高清直播', 'idx': 3034}
# {'name': '蘑菇街-网红直播搭配的购物特卖平台', 'idx': 3065}
# {'name': 'Keep - 移动健身教练 自由运动场', 'idx': 3073}
# {'name': '美团 - 吃喝玩乐全都有', 'idx': 3074}
# {'name': '百度贴吧HD', 'idx': 3078}
# {'name': '腾讯手机管家-拦截骚扰电话的QQ安全助手', 'idx': 3107}
# {'name': 'Color•多彩手帐', 'idx': 3173}
# {'name': '饿了么外卖-大牌美食，折扣热卖', 'idx': 3180}
# {'name': '宝宝树孕育-火爆的备孕怀孕育儿社区', 'idx': 3217}
# {'name': '懂球帝 - 足球迷必备神器', 'idx': 3264}
# {'name': '今日头条 - 热点新闻资讯、娱乐视频', 'idx': 3283}
# {'name': '天猫-购物', 'idx': 3289}
# {'name': '沪江开心词场-英语、日语、韩语学习助手', 'idx': 3311}
# {'name': '倩女幽魂-周年庆资料片开启新主角剧情', 'idx': 3342}
# {'name': '欢乐斗地主•腾讯', 'idx': 3349}
# {'name': '百度糯米-电影,美食团购', 'idx': 3383}
# {'name': '搜狐新闻—新闻热点资讯掌上阅读软件', 'idx': 3384}
# {'name': '手机京东-首次购买可领取188元优惠券', 'idx': 3432}
# {'name': 'QQ游戏大厅HD', 'idx': 3495}
# {'name': '赶集网-工作生活啥都有！', 'idx': 3546}
# {'name': '携程旅行-酒店、机票、火车票预订助手', 'idx': 3562}
# {'name': '腾讯微云-安全备份共享文件和照片', 'idx': 3576}
# {'name': 'QQ安全中心', 'idx': 3577}
# {'name': '招商银行', 'idx': 3584}
# {'name': '去哪儿旅行-预订机票酒店火车票特价旅游自由行', 'idx': 3626}
# {'name': '暴风影音-BaoFeng Player', 'idx': 3634}
# {'name': '闲鱼-让你的闲置游起来', 'idx': 3638}
# {'name': '内涵段子 - 精选搞笑图片、视频', 'idx': 3669}
# {'name': '斗鱼--王者大神在直播', 'idx': 3694}
# {'name': 'VVebo - 微博客户端', 'idx': 3717}
# {'name': '中国建设银行', 'idx': 3723}
# {'name': '中国联通手机营业厅客户端(官方版)', 'idx': 3762}
# {'name': '电信营业厅', 'idx': 3767}
# {'name': '随手记专业版 for  iPad', 'idx': 3796}
# {'name': '美团外卖-甜点生鲜等零食配送，鲜花蛋糕准时必达', 'idx': 3851}
# {'name': '驾考宝典-2017最新考驾照驾校学车驾考通', 'idx': 3902}
# {'name': '欧路英语词典 Eudic 增强版', 'idx': 3913}
# {'name': '腾讯欢乐麻将全集', 'idx': 3919}
# {'name': '宜搜小说-亿万网友共享高品质阅读离线追更', 'idx': 3932}
# {'name': '夢王国と眠れる100人の王子様', 'idx': 3948}
# {'name': '航旅纵横PRO-官方航班动态、手机值机、机票', 'idx': 3952}
# {'name': '鬼畜-一亿人都在用的聊天必备神器!', 'idx': 3973}
# {'name': '中国银行手机银行', 'idx': 3974}
# {'name': 'QQ阅读-拥有海量原著小说的电子书阅读器', 'idx': 4017}
# {'name': '武林群侠传—经典单机武侠RPG', 'idx': 4078}
# {'name': '咕咚-你的跑步骑行运动社区', 'idx': 4108}
# {'name': '中国工商银行', 'idx': 4155}
# {'name': '一骑当千OL-万人国战（Legend Of Warrior）', 'idx': 4156}
# {'name': '百度外卖 -美食订餐品质生活，超市水果安全到家', 'idx': 4177}
# {'name': '腾讯微云HD-安全备份共享文件和照片', 'idx': 4234}
# {'name': '飞常准Pro-全球航班查询机票酒店预订', 'idx': 4264}
# {'name': '车轮查违章-2017全国车辆违章查询助手', 'idx': 4281}
# {'name': '今日头条(专业版) - 推荐热点新闻资讯、娱乐视频', 'idx': 4283}
# {'name': '机票、火车票、汽车票预定助手 for 铁路12306', 'idx': 4288}
# {'name': '招商银行信用卡掌上生活', 'idx': 4326}
# {'name': '百度手机卫士－wifi管家照片管理防骚扰安全助手', 'idx': 4342}
# {'name': '汽车之家-提供新车,二手车报价及资讯', 'idx': 4364}
# {'name': 'クックパッド - No.1料理レシピ検索アプリ', 'idx': 4373}
# {'name': '我想有个家', 'idx': 4382}
# {'name': '易到 - 低价专车,高品质出行', 'idx': 4385}
# {'name': '球球大作战', 'idx': 4405}
# {'name': '仙劍奇俠傳1 DOS懷舊版', 'idx': 4467}
# {'name': '作业帮-小初高学生拍照答疑学习辅导助手', 'idx': 4483}
# {'name': '猫眼电影 - 一网打尽好电影', 'idx': 4484}
# {'name': '唯品会-欢乐颂2独家电商 同款热卖', 'idx': 4489}
# {'name': '返利-专注网购省钱的APP', 'idx': 4519}
# {'name': 'YY HD-和美女帅哥主播视频聊天的直播软件', 'idx': 4548}
# {'name': '一起作业学生端-中小学霸口袋学习辅导助手', 'idx': 4569}
# {'name': '搜房网房天下-新房二手房租房交易平台', 'idx': 4585}
# {'name': '更加令人感动的养成游戏「昭和杂货店物语２」', 'idx': 4608}
# {'name': '金庸群侠传—全自由单机武侠RPG', 'idx': 4624}
# {'name': '去哪儿旅行HD-总有你要的低价', 'idx': 4626}
# {'name': '安居客-二手房、新房、租房的找房助手', 'idx': 4634}
# {'name': '秒拍-超火爆短视频分享平台', 'idx': 4643}
# {'name': 'WiFi钥匙—万能wifi密码钥匙', 'idx': 4660}
# {'name': '中国移动手机营业厅(中国移动官方)', 'idx': 4662}
# {'name': 'same - 就是聊得来', 'idx': 4700}
# {'name': '腾讯新闻HD-最资深的阅读软件', 'idx': 4719}
# {'name': '唯品会 HD 全球精选，正品特卖', 'idx': 4817}
# {'name': '同花顺至尊版', 'idx': 4832}
# {'name': '小咖秀-全民视频才艺直播社区', 'idx': 4834}
# {'name': '当当-正品秒杀，首单立减5元', 'idx': 4849}
# {'name': '1号店-全球超市 轻松到家', 'idx': 4857}
# {'name': 'comico/人気オリジナル漫画が毎日更新！/コミコ', 'idx': 4885}
# {'name': '格斗学院-社团争霸圣装崛起，热血高校一触即发', 'idx': 4888}
# {'name': 'おそ松さんのへそくりウォーズ\u3000〜ニートの攻防〜', 'idx': 4894}
# {'name': '虫虫大作战-经典休闲蛇蛇', 'idx': 4947}
# {'name': '农行掌上银行', 'idx': 4948}
# {'name': '同程旅游-中国汽车票自助周边游海外跟团订票', 'idx': 4952}
# {'name': '魔窟-无尽的地下城', 'idx': 5003}
# {'name': '無制限で人気音楽聴き放題！ - Music Bank（ミュージックバンク）', 'idx': 5029}
# {'name': '途牛旅游-订机票酒店，查旅行景点门票', 'idx': 5038}
# {'name': 'ナビタイムの乗り換え案内 - 遅延情報やバス時刻表を案内するアプリ', 'idx': 5070}
# {'name': '51信用卡管家', 'idx': 5081}
# {'name': '少年西游记－西游卡牌王者之作', 'idx': 5110}
# {'name': '北京浮生记', 'idx': 5129}
# {'name': '聚美优品-新用户专享160元现金券', 'idx': 5160}
# {'name': '诸神战纪IV:战神崛起', 'idx': 5163}
# {'name': '洋码头—正品保证海外买手带你全球购洋货', 'idx': 5171}
# {'name': '开心消消乐®', 'idx': 5194}
# {'name': '苏宁易购-新人专享大礼包', 'idx': 5225}
# {'name': '熊猫直播-王者大神主播带你荣耀开黑', 'idx': 5229}
# {'name': '虎牙直播-热门高清游戏互动直播平台', 'idx': 5233}
# {'name': 'タップル誕生 - 出会いアプリで趣味から恋活・婚活', 'idx': 5242}
# {'name': '浪漫庄园(自由创造你的梦想)', 'idx': 5253}
# {'name': '58同城-招聘找工作兼职租房软件', 'idx': 5283}
# {'name': '京东金融-【618周年庆】新人领千元好礼', 'idx': 5297}
# {'name': '广东移动手机营业厅-话费流量一手掌握，专属优惠定期发放', 'idx': 5302}
# {'name': '幻獣契約クリプトラクト', 'idx': 5304}
# {'name': 'GANMA! - 漫画が制限ナシで読み放題のマンガアプリ', 'idx': 5325}
# {'name': '小猿搜题-中小学拍照搜题作业帮手', 'idx': 5331}
# {'name': '驴妈妈旅游-订景点门票机票火车票特价酒店', 'idx': 5345}
# {'name': '单机群侠传-金庸群侠传口袋版', 'idx': 5351}
# {'name': '淘票票 - 原淘宝电影，选座购票必备', 'idx': 5373}
# {'name': '腾讯体育-NBA全网独播', 'idx': 5376}
# {'name': 'AbemaTV-インターネットテレビ局', 'idx': 5386}
# {'name': 'ダイエットが続く！人気のカロリー・体重管理アプリ 「もぐたん」', 'idx': 5392}
# {'name': 'kurashiru [クラシル] - 料理レシピ動画数No.1', 'idx': 5404}
# {'name': '私のヒモ男～イケメン拾いました～恋愛・放置ゲーム', 'idx': 5416}
# {'name': '高德地图HD', 'idx': 5430}
# {'name': '梦幻西游互通版', 'idx': 5439}
# {'name': '去哪儿攻略—查游记旅游攻略，订机票酒店', 'idx': 5443}
# {'name': '乐视体育—英超欧冠F1高清直播', 'idx': 5453}
# {'name': '史上最强的大脑4-超级王者(时代永恒小强)', 'idx': 5456}
# {'name': '网易考拉海购—新人免费领取1000元优惠券', 'idx': 5473}
# {'name': '她社区-只有女生的社区！', 'idx': 5474}
# {'name': '转转-更专业的二手闲置交易平台', 'idx': 5475}
# {'name': '51信用卡管家Pro', 'idx': 5476}
# {'name': '上海移动掌上营业厅', 'idx': 5484}
# {'name': '全民炸金花-首款含电玩城百家乐的棋牌游戏', 'idx': 5496}
# {'name': '【2017年の運勢決定版】ゲッターズ飯田の占い', 'idx': 5514}
# {'name': '虎牙直播HD-热门高清游戏互动直播平台', 'idx': 5520}
# {'name': '单机三国志2-铜雀台资料片 天天都玩', 'idx': 5541}
# {'name': '洋菓子店ローズ ～ほのぼの再建記～', 'idx': 5554}
# {'name': '12オーディンズ - 王道RPG', 'idx': 5555}
# {'name': 'かなもじ', 'idx': 5571}
# {'name': '达令全球好货－正品免税，带你购全球', 'idx': 5580}
# {'name': '三国杀传奇-神将觉醒', 'idx': 5585}
# {'name': '花椒直播-高清美颜直播互动平台', 'idx': 5587}
# {'name': '全民夺宝-时尚购潮流商品平台', 'idx': 5598}
# {'name': '特种部队-跨服竞技TCG军事策略游戏', 'idx': 5628}
# {'name': '途家-全球公寓民宿预订平台', 'idx': 5633}
# {'name': 'エレメンタル ファンタジー - 高精細３ＤアクションＲＰＧ', 'idx': 5636}
# {'name': '驾校一点通-保过版，2017最新驾考学车宝典', 'idx': 5642}
# {'name': '平安WiFi-手机必备的万能WiFi上网钥匙', 'idx': 5644}
# {'name': '天天快报 - 最热门的新闻资讯软件', 'idx': 5660}
# {'name': '狼人之夜', 'idx': 5662}
# {'name': '家长通-一起作业旗下家长端的同步课堂点读机', 'idx': 5664}
# {'name': '小猿搜题HD-中小学拍照搜题作业帮手', 'idx': 5675}
# {'name': '单机三国志-不抽卡无体力,战个痛快', 'idx': 5679}
# {'name': '蚂蚁聚宝—蚂蚁金服旗下投资理财平台', 'idx': 5693}
# {'name': '家計簿マネーフォワード-自動連携で簡単 人気の家計簿', 'idx': 5701}
# {'name': 'ゆるドラシル -本格派神話RPG-', 'idx': 5704}
# {'name': '书香云集Pro-小说电子书免费看书读书听书追书无广告阅读器', 'idx': 5711}
# {'name': '买火车票Pro', 'idx': 5718}
# {'name': '直播吧(官方版)-体育从这里开始', 'idx': 5730}
# {'name': '永生劫 — 单机回合仙侠RPG', 'idx': 5732}
# {'name': '江湖风云录-超自由武侠剧情角色扮演手游', 'idx': 5733}
# {'name': '工银融e联', 'idx': 5737}
# {'name': 'ひみつの出会い探しはバクアイ-無料の出会いチャットアプリで友達作り', 'idx': 5744}
# {'name': 'pixivコミック - みんなのマンガアプリ', 'idx': 5747}
# {'name': '【真・お絵かきパズル】〇〇投げてみた結果ｗｗ\u3000完全無料！', 'idx': 5748}
# {'name': '宜人贷借款', 'idx': 5755}
# {'name': '【明星恋爱】偶像之路TIME TO STAR', 'idx': 5758}
# {'name': '실시간 날씨', 'idx': 5759}
# {'name': '零基础学音标', 'idx': 5764}
# {'name': '记账·圈子账本(专业版)—可共享的全能记帐本软件', 'idx': 5769}
# {'name': '宾果消消消 -赵丽颖代言', 'idx': 5771}
# {'name': '戦艦帝国-200艘の実在戦艦を集めろ (2周年記念&世界2000万DL)', 'idx': 5779}
# {'name': 'Jメール 出会える人気の匿名SNS出会い系アプリ', 'idx': 5786}
# {'name': '楽天カード', 'idx': 5787}
# {'name': '蜜芽 - 生娃养娃上蜜芽', 'idx': 5788}
# {'name': '360手机浏览器-安全上网看新闻、安心搜索、极速抢票', 'idx': 5792}
# {'name': '华尔街见闻（专业版）-全球财经新闻精选', 'idx': 5793}
# {'name': 'لغز الماضي - اربع اجزاء', 'idx': 5795}
# {'name': 'スロットマニア・フィーバー～本場ラスベガススロット', 'idx': 5810}
# {'name': '小历 - 通知中心日历', 'idx': 5811}
# {'name': '放置江湖: 大侠的成长之路（高自由度的武侠体验）', 'idx': 5823}
# {'name': "マクドナルド - McDonald's Japan", 'idx': 5825}
# {'name': '借贷宝-直投熟人更高明', 'idx': 5833}
# {'name': '大根にしがみつく女子高生', 'idx': 5839}
# {'name': '熊猫直播HD-最娱乐的直播平台', 'idx': 5845}
# {'name': 'カロリー管理（痩せるアプリ）', 'idx': 5850}
# {'name': 'マンガ図書館Z -人気漫画が読み放題！', 'idx': 5852}
# {'name': '微软识花', 'idx': 5857}
# {'name': 'ホットペッパービューティー/サロン予約', 'idx': 5861}
# {'name': 'ようとん場', 'idx': 5869}
# {'name': '自动证件照 - 智能证件照相机美图美颜编辑,制作学生证件照', 'idx': 5883}
# {'name': '翼支付-只为简单生活', 'idx': 5885}
# {'name': '银联钱包- 银行卡管家，扫码支付享优惠', 'idx': 5887}
# {'name': 'HIGO-全球奢侈品牌和设计师品牌购买平台', 'idx': 5889}
# {'name': 'ヤフオク! 利用者数NO.1のオークション、フリマアプリ', 'idx': 5893}
# {'name': '战神之怒', 'idx': 5898}
# {'name': '宜搜小说-热门网络书籍看书追更必备神器', 'idx': 5900}
# {'name': '征戦エクスカリバー', 'idx': 5902}
# {'name': '【はらぺこパズル】ごはんに恋をした', 'idx': 5903}
# {'name': '棒棒糖-宝宝的世界衣橱', 'idx': 5908}
# {'name': '快读免费小说-最热网络小说追书神器全本下载阅读器', 'idx': 5914}
# {'name': 'ダウト～嘘つきオトコは誰？～', 'idx': 5919}
# {'name': '腾讯WiFi管家-手机安全免费WiFi', 'idx': 5922}
# {'name': '超ヒモ理論 ～働きたくないでござる～', 'idx': 5924}
# {'name': 'flick（フリック）- みんなの顔文字キーボードから名前が変わりました', 'idx': 5926}
# {'name': '日课——给每一位好读诗的人！', 'idx': 5957}
# {'name': '挖财宝理财-预期年化收益高达12%', 'idx': 5960}
# {'name': 'mememo(ミーメモ)ダイエット〜生理日予測まで女性サポート', 'idx': 5964}
# {'name': '企业微信', 'idx': 5972}
# {'name': '全民坦克联盟—坦克帝国官方正版', 'idx': 5974}
# {'name': 'フリル(FRIL) - 満足度No.1 のフリマアプリ', 'idx': 5975}
# {'name': '鏡の中のプリンセス Love Palace', 'idx': 5976}
# {'name': 'DELISH KITCHEN - レシピ動画で料理を簡単に', 'idx': 5977}
# {'name': '中国搜索-国家权威搜索', 'idx': 5979}
# {'name': '新概念英语2015最新版-英美全四册', 'idx': 5981}
# {'name': '楽天市場 for iPad', 'idx': 5987}
# {'name': '优信二手车-二手车买车卖车评估交易平台', 'idx': 5992}
# {'name': 'Eye Training Cocololo-3dステレオグラム視力回復アプリ-', 'idx': 5994}
# {'name': '贝贝-8000万妈妈信赖的母婴正品特卖拼团商城', 'idx': 5996}
# {'name': '本気で英会話！ペラペラ英語\u3000英単語・リスニング・TOEICの学習にも！', 'idx': 6005}
# {'name': '弹弹堂S- 巴萨传奇助阵 弹弹堂手游官方版', 'idx': 6006}
# {'name': '交通银行信用卡买单吧', 'idx': 6010}
# {'name': '秀色秀场-网红直播 聊天交友', 'idx': 6015}
# {'name': '上司と秘密の2LDK\u3000Love Happening', 'idx': 6018}
# {'name': 'ゲーム発展国＋＋', 'idx': 6023}
# {'name': 'mazec - 手書き日本語入力ソフト', 'idx': 6027}
# {'name': '迷你世界-国产精品沙盒联机生存建造游戏', 'idx': 6028}
# {'name': '脱出ゲーム 1K', 'idx': 6030}
# {'name': '【謎解き】罪と罰-ノベルゲーム型 推理アドベンチャー', 'idx': 6036}
# {'name': 'DayDayCook － 日日煮', 'idx': 6038}
# {'name': '平安金管家 — 值得信赖的移动金融生活管家', 'idx': 6040}
# {'name': 'ファンタジードライブ【快進撃3DRPG】', 'idx': 6042}
# {'name': '平安好车主-用车助手,安全管家', 'idx': 6044}
# {'name': 'モン娘は～れむ【モンはれ】', 'idx': 6049}
# {'name': 'ウィズダム英和・和英辞典 2', 'idx': 6050}
# {'name': '百度钱包-金融信贷和理财投资优选', 'idx': 6064}
# {'name': 'もやししゃちょー', 'idx': 6068}
# {'name': '拼多多 - 1亿人都在拼的购物App', 'idx': 6069}
# {'name': '舰娘收藏2-注册就送辽宁号', 'idx': 6075}
# {'name': '【よく当たる】手相鑑定〜選べる鑑定ジャンル(人生運、仕事運、恋愛運)', 'idx': 6082}
# {'name': '俺と鬼嫁の100日戦記', 'idx': 6085}
# {'name': 'ホストのアブナイ世界', 'idx': 6086}
# {'name': '非诚勿扰-中国最大免费婚恋交友平台', 'idx': 6087}
# {'name': '感動アプリ！無料ゲーム Japanese Gacha', 'idx': 6088}
# {'name': 'UDONちゅるん', 'idx': 6090}
# {'name': 'Suicaチャージ', 'idx': 6094}
# {'name': '家园7：雪城增强版', 'idx': 6097}
# {'name': 'ごちうさアラーム～チノ編～', 'idx': 6114}
# {'name': '我的密码-极简账号备忘录，安全记录管家', 'idx': 6123}
# {'name': '大航海世界（风靡日本航海手游《壮绝大航海》正版授权）', 'idx': 6125}
# {'name': '【カノピッピ大作戦】ギャルがオタクに恋をした/脱ギャル系彼女育成ゲーム', 'idx': 6127}
# {'name': '天天麻将-有奖励的麻将玩法全集', 'idx': 6130}
# {'name': '熱血高校！胴上げ部', 'idx': 6133}
# {'name': 'Uber优步中国', 'idx': 6145}
# {'name': '脱出ゲーム 謎解き部屋からの脱出', 'idx': 6146}
# {'name': '10 – 頭を良くするパズル', 'idx': 6147}
# {'name': 'どうぶつしょうぎ(公式)', 'idx': 6149}
# {'name': 'ぼっちでもリア充になれる奇跡のアプリ。〜恋する缶づめ。〜', 'idx': 6156}
# {'name': '美食杰-让吃饭变简单(VIP版)', 'idx': 6157}
# {'name': '脱出ゲーム\u3000研究所からの脱出', 'idx': 6162}
# {'name': '脱出ゲーム\u3000Cottage', 'idx': 6164}
# {'name': '【謎解き】自称カノジョからの病みすぎメッセージ', 'idx': 6165}
# {'name': '謎解き ジェスチャーゲーム - 何してる？', 'idx': 6167}
# {'name': '銀魂 公式連載アプリ〜銀魂の漫画が毎週１巻読めるアプリ〜', 'idx': 6168}
# {'name': 'QRコードリーダー for iPhone - 無料で使えるQRコード読み取り用アプリ', 'idx': 6170}
# {'name': 'ぷちドラシル 〜ゆるドラ外伝〜', 'idx': 6171}
# {'name': '激ムズ！ねこ階段', 'idx': 6175}
# {'name': '迷你屠龙传(1.76经典休闲挂机版)', 'idx': 6176}
# {'name': '求生无限 - 无限流生存挑战大冒险', 'idx': 6182}
# {'name': '街机格斗王', 'idx': 6183}
# {'name': '我叫MT3-回合制魔幻世界 大型公会副本开荒', 'idx': 6184}
# {'name': '最高警戒', 'idx': 6185}
# {'name': '不思議雑貨店ローズ ～ほのぼの再建記～', 'idx': 6187}
# {'name': '脱出ゲーム KOTATSU', 'idx': 6188}
# {'name': '好きになったら負け。\u3000完全無料！女性向けイケメン恋愛ゲーム', 'idx': 6189}
# {'name': '霸王卧龙传', 'idx': 6190}
# {'name': '【推理ゲーム】 YASU-第7捜査課事件ファイル-', 'idx': 6192}
# {'name': '精度93％ 絶望の心理テスト', 'idx': 6193}
# {'name': '脱出ゲーム\u3000わたしをみつけて\u3000-おじいさんとわたしの物語-', 'idx': 6194}
# {'name': '激おこ!! はじめしゃちょー\u3000なんなんですか!?', 'idx': 6195}
# {'name': '新超级群英传OL-单机党必玩的三国群英手游', 'idx': 6197}
# {'name': '中高英文法を10時間で！マジグラ', 'idx': 6198}
# {'name': '当たる占い師【水晶玉子】特別鑑定書≪無料占いあり≫', 'idx': 6199}
# {'name': '脱出ゲーム\u3000都市伝説〜杉沢村からの脱出〜', 'idx': 6200}
# {'name': '脱出ゲーム - 書道教室 -  "漢字"の謎に満ちた部屋からの 脱出', 'idx': 6201}
# {'name': '《女性口コミNo.1》水晶玉子の幸福領域占い', 'idx': 6203}
# {'name': 'ブラックバイトはじめました。２\u3000～居酒屋編～', 'idx': 6204}
# {'name': '脱出ゲーム\u3000Night Room', 'idx': 6206}
# {'name': 'ねこみっけ - おもしろい人気無料ゲーム', 'idx': 6207}
# {'name': '激ムズ！ねこじゃんぷ２', 'idx': 6209}
# {'name': '脱出ゲーム - Solid - 無機質な部屋からの 脱出', 'idx': 6211}
# {'name': '脱出ゲーム 古城からの脱出', 'idx': 6213}
# {'name': '病みカワカメラ', 'idx': 6214}
# {'name': '美播 - 玩不尽的真人游戏', 'idx': 6215}
# {'name': '二炮手-同名抗战狙击手游(孙红雷主演)', 'idx': 6218}
# {'name': '陌恋-同城高颜值寂寞美女帅哥激情交友聊天神器！', 'idx': 6220}
# {'name': '脱出ゲーム\u3000ぼくのおねがいきいて', 'idx': 6223}
# {'name': 'Dark Money-無料のお金稼ぎギャンブルゲーム-', 'idx': 6224}
# {'name': '【ドレ？ドコ？】脱出ゲーム感覚の謎解きパズルゲーム', 'idx': 6226}
# {'name': 'ペットとあそぼ！- 声を選んで写真がしゃべる、しりとりゲームおしゃべりペット！犬・猫好き癒し系アプリ', 'idx': 6227}
# {'name': '烈焰王座HD - 卡牌与挂机结合的养成放置游戏', 'idx': 6229}
# {'name': '擬人缶～俺のペットが少女になった～', 'idx': 6232}
# {'name': '僕の彼女は浮気なんかしない', 'idx': 6235}
# {'name': '大话问仙 - 与众不同的萌派仙侠回合游戏体验(送神器)', 'idx': 6236}
# {'name': '注文の多いブサ猫軒', 'idx': 6242}
# {'name': 'ごちうさアラーム～リゼ編～', 'idx': 6244}
# {'name': 'You hate me? わたしのこと きらい？', 'idx': 6245}
# {'name': 'ゲームセンター倶楽部', 'idx': 6246}
# {'name': '脱出ゲーム\u3000In My Heart', 'idx': 6248}
# {'name': '蜀山诛魔纪-古装恋爱仙侠动作手游·MMO端游品质', 'idx': 6250}
# {'name': '大挂西游 - 降魔之路官方正版', 'idx': 6251}
# {'name': '脱出ゲーム - KINDERGARTEN - 子供にイタズラされたリビングからの 脱出', 'idx': 6253}
# {'name': 'ピグパーティ - きせかえ・アバターで楽しむトークアプリ', 'idx': 6255}
# {'name': '青空発掘カンパニー', 'idx': 6256}
# {'name': '健康献立レシピ提案 オーガニック “Ohganic"', 'idx': 6257}
# {'name': 'ミリオン行進曲', 'idx': 6258}
# {'name': 'ナニワ金融道\u3000全巻無料のマンガアプリ', 'idx': 6261}
# {'name': 'おかんからのメッセ - ほのぼの謎解きゲーム', 'idx': 6265}
# {'name': 'NAVIRO(ナビロー) - カーナビ/バイクナビ/徒歩ナビが使える高性能ナビアプリ', 'idx': 6266}
# {'name': '最長１週間の献立が簡単に作れるme:new（ミーニュー）', 'idx': 6268}
# {'name': '皮皮四川麻将', 'idx': 6269}
# {'name': 'ワンダークラウン', 'idx': 6271}
# {'name': '网商银行', 'idx': 6272}
# {'name': 'サッカーカーニバル', 'idx': 6273}
# {'name': '龙珠直播-高清游戏娱乐直播平台', 'idx': 6274}
# {'name': '性教育そうだったのか！世界一まなべる保健体育クイズ(画像付き)', 'idx': 6275}
# {'name': '乐享动-有运动音乐推荐的计步器', 'idx': 6277}
# {'name': 'らぶいずふぉーえばー #泣けるピアノゲーム', 'idx': 6278}
# {'name': '豪快ショット連発！ストレス発散テニスゲーム「エアK」', 'idx': 6279}
# {'name': 'おじクエ - OJISAN QUEST - タップRPG -', 'idx': 6280}
# {'name': '殺意の国のアリス -狂気に目覚めた童話の主人公たち-', 'idx': 6281}
# {'name': '【脳トレ】ROLL -ころがす、はめる、きえる-', 'idx': 6282}
# {'name': '操作しやすいナンプレ！目に優しい パズルゲーム 800問', 'idx': 6283}
# {'name': 'シロクマ先生のゆるくない英文法', 'idx': 6285}
# {'name': '剑仙传奇·蜀山修仙之独步天下', 'idx': 6286}
# {'name': '無料ゲーム タッチザナンバー（Touch the numbers）計算の脳トレでパズル！', 'idx': 6287}
# {'name': 'ここに墓を建てよう', 'idx': 6288}
# {'name': '天天萌斗—超级萌红将免费领取，上千少年超级英雄形象，让你在多次元大陆享受卡牌萌斗罗乐趣', 'idx': 6289}
# {'name': '麻雀物語３ 役満乱舞の究極大戦', 'idx': 6291}
# {'name': 'NINE 対戦型脳トレ -目指せ賞金王！-', 'idx': 6293}
# {'name': '派派激情版-寂陌陌声人交友神器', 'idx': 6294}
# {'name': 'やる夫のチャリ', 'idx': 6295}
# {'name': 'シルエットクイズ～人気マンガ・映画アニメキャラ・芸能人で暇つぶし脳トレ', 'idx': 6296}
# {'name': '人众金服[回馈版]-高收益理财软件', 'idx': 6301}
# {'name': 'クリアしてみろよ？ 神ゲー アクション ゲーム', 'idx': 6302}
# {'name': '懸賞パズルパクロス２', 'idx': 6303}
# {'name': '伙星 - 随手拍出明星一样的MV', 'idx': 6306}
# {'name': 'iSNOB 小众精品爱好者的私藏Top 10', 'idx': 6307}
# {'name': 'マジ死にゲー', 'idx': 6308}
# {'name': 'まんが一本道〆', 'idx': 6309}
# {'name': '创客金融-高收益银行存管投资理财平台', 'idx': 6310}
# {'name': '镜花缘：两世英雄情缘,数年问仙修道', 'idx': 6311}
# {'name': 'ディグラム恋愛診断', 'idx': 6312}
# {'name': '盗墓OL-精绝女王', 'idx': 6314}
# {'name': '恋愛消滅ボタン ~ 無料 泣ける恋愛小説 放置ゲーム ~', 'idx': 6315}
# {'name': '街机游戏厅 - 电玩游戏合集火爆改版', 'idx': 6317}
# {'name': 'ポケット戦国 -戦略と戦術で歴史を作れ！-【本格派 戦国シミュレーション】', 'idx': 6318}
# {'name': '视吧-全民手机直播', 'idx': 6319}
# {'name': '龙之觉醒-热血经典RPG，回味激燃岁月', 'idx': 6321}
# {'name': 'ニュースパス -かんたん操作で必要なニュースがすぐ読めるニュースアプリ', 'idx': 6323}
# {'name': '9回裏だけ甲子園', 'idx': 6324}
# {'name': '捨て猫レスキュー', 'idx': 6325}
# {'name': '战姬物语-亚洲顶级画师操刀,颜值爆表手游', 'idx': 6326}
# {'name': '口袋苍穹-首日送萧炎，重返斗气大陆', 'idx': 6328}
# {'name': '镜花奇缘 - 最新诛仙类卡牌传奇手游游戏', 'idx': 6329}
# {'name': '妙资理财（九周年版)-高收益理财投资平台', 'idx': 6331}
# {'name': '君の目的はボクを殺すこと。', 'idx': 6332}
# {'name': '召喚AKUMA/悪魔合体召喚～育成シミュレーションRPGゲーム', 'idx': 6335}
# {'name': '都市异能小说-全本经典有声小说听书阅读神器', 'idx': 6336}
# {'name': 'ALOE -ダイエット・ヨガ・エクササイズ…健康美を追求する女性の人気無料ニュースアプリ', 'idx': 6337}
# {'name': 'ポケ電バッテリー for ポケモンGO', 'idx': 6338}
# {'name': 'はじめん\u3000～はじめとつくる動画生活～', 'idx': 6339}
# {'name': 'DARUMA -目玉を転がして入れてください-', 'idx': 6340}
# {'name': 'お弁当をつくろう！ママごっこ－お仕事体験知育アプリ', 'idx': 6344}
# {'name': '南国物語', 'idx': 6345}
# {'name': 'TOEIC®TEST実力判定『アプトレ』', 'idx': 6346}
# {'name': 'お前は俺の女だろーが【胸キュン恋愛、リア充ストーリー！？】', 'idx': 6348}
# {'name': '猎魔传奇-塔塔&推塔挂机私服手游', 'idx': 6349}
# {'name': 'ブラックバイトはじめました。俺の嫁に捧げるストーリー【放置】', 'idx': 6350}
# {'name': 'GeniusTest！天才てすと', 'idx': 6352}
# {'name': '牛タン牛タン牛タンタン', 'idx': 6353}
# {'name': '炎上なう -つぶやきSNS風シミュレーションゲーム-', 'idx': 6354}
# {'name': 'Test your color IQ！カラーIQ診断テスト２', 'idx': 6355}
# {'name': '欢乐颂合集—刘涛、蒋欣等主演电视剧同名原著', 'idx': 6356}
# {'name': '传说一刀 - 一刀一级PK爆屠龙', 'idx': 6357}
# {'name': '面倒だがトリあえずキーボード ～ さわりたくなるキーボード', 'idx': 6358}
# {'name': 'アキラメロン【メロンを受け止める、チョイムズゲー】', 'idx': 6359}
# {'name': '面白ニュースを超快適に読める!!まとめのまとめMM', 'idx': 6360}
# {'name': '真モグモグ風林火山2', 'idx': 6362}
# {'name': '妙资理财-福利版（年化14.8%注册送1万体验金）', 'idx': 6363}
# {'name': '诺诺镑客—让财富升值', 'idx': 6364}
# {'name': 'これやったことない人いる？', 'idx': 6365}
# {'name': '鴨川等間隔の法則', 'idx': 6366}
# {'name': 'PP基金-随时提现的投资理财平台', 'idx': 6367}
# {'name': '多纳餐厅2', 'idx': 6368}
# {'name': '一言-记录字句，发现共鸣', 'idx': 6369}
# {'name': '坦克新纪元——经典红警狂热回归', 'idx': 6370}
# {'name': '全民暴力摩托-暴力摩托3d免费真实赛车小游戏', 'idx': 6371}
# {'name': '女の子のための女子トレンドまとめアプリ-ウーマガジン-', 'idx': 6372}
# {'name': '空格－更优秀的个人技能交易平台', 'idx': 6373}
# {'name': 'マッチングならSecret- 友達・恋人探しSNS', 'idx': 6374}
# {'name': '極限ドリブル～神の子 edition～', 'idx': 6376}
# {'name': '暴打三国志-经典RPG角色扮演动作卡牌策略手游', 'idx': 6379}
# {'name': 'ゲームプレイで賞金ゲット！ポットハンター', 'idx': 6382}
# {'name': 'Fit 私人健身教练-超有效的健康运动减肥软件', 'idx': 6384}
# {'name': 'シンデレラブレイド2', 'idx': 6385}
# {'name': 'ピンポンカーブ  君の反射神経Lvはいくつ？  #天才求ム', 'idx': 6386}
# {'name': 'オオカミ姫 [ みんなで協力！ターン制ギルドバトルRPG ]', 'idx': 6388}
# {'name': 'Spot the Difference!診断テスト', 'idx': 6389}
# {'name': '年賀状2018｜おしゃれなスマホで写真年賀状2018', 'idx': 6393}
# {'name': '求恋爱 专业版-高端恋爱相亲婚恋交友神器,同城寂寞单身男女聊天约会找对象平台', 'idx': 6394}
# {'name': '口袋全明星', 'idx': 6397}
# {'name': 'Are you a psychopath? 怖い心理テスト', 'idx': 6398}
# {'name': '桃太郎の\u3000はなし\u3000は終わっていない #泣ける昔話ノベルゲーム', 'idx': 6399}
# {'name': '多盈理财-正规手机投资金融理财产品', 'idx': 6400}
# {'name': '勇士与魔龙', 'idx': 6401}
# {'name': '诸神战纪竞技场：超神大冒险(无尽关 排行榜 动作类横版过关游戏)', 'idx': 6402}
# {'name': '金陵十三钗－王丽坤代言,伴你穿越红楼今梦', 'idx': 6403}
# {'name': 'おチャベリ-ビデオ通話でマッチングアプリ', 'idx': 6404}
# {'name': '少年勇者团 (Combo Warrior)-日系Q萌即时战斗消除RPG手游', 'idx': 6405}
# {'name': '公牛炒股-证券开户交易软件', 'idx': 6407}
# {'name': '流しそうめんエクストリーム', 'idx': 6408}
# {'name': '商品バーコードで賞味期限を通知 Limiter2 (リミッター)', 'idx': 6409}
# {'name': '【放置ゲー】壁ドンしたら人生変わった ～グリモアのキャラ達に壁ドン！？～', 'idx': 6410}
# {'name': 'トクバイ - チラシアプリ／スーパーの特売情報で節約 -', 'idx': 6411}
# {'name': '戦え！プリンセスドール', 'idx': 6414}
# {'name': '無料アプリ暇つぶしゲーム【BOKEMON】〜トボケモンスターを進化させるで〜', 'idx': 6415}
# {'name': 'MINE［マイン］ファッション/コーディネート動画アプリ', 'idx': 6416}
# {'name': 'Casino Girl-お金稼ぎ美少女育成ゲーム-', 'idx': 6418}
# {'name': '航海帝国HD 唯一正版授权 传承经典 统御大航海强者时代', 'idx': 6419}
# {'name': '「おつぼね」“あるある”エンターテイメントストーリー：OTUBO（お局）', 'idx': 6420}
# {'name': '花粉儿-女性、母婴闲置交易平台', 'idx': 6422}
# {'name': 'the SOUL of SEVENS【ソウル オブ セブンス】', 'idx': 6423}
# {'name': 'グルータ / 最新ニュースまとめをグループチャットで！(Grouta)', 'idx': 6425}
# {'name': 'SmartForm - 見積書・納品書・請求書・領収書作成ソフトの新定番！', 'idx': 6426}
# {'name': '今日、彼女が死んだ', 'idx': 6428}
# {'name': 'ひとりぼっち惑星', 'idx': 6429}
# {'name': '黄金日-贵金属理财投资黄金白银', 'idx': 6430}
# {'name': 'トリセツメーカー\u3000トリセツ診断', 'idx': 6431}
# {'name': '奇跡のメガネ\u3000-恋愛シミュレーションゲーム', 'idx': 6432}
# {'name': '片手キーボードPRO', 'idx': 6434}
# {'name': 'オーブGETマルチ掲示板！ for モンスト', 'idx': 6435}
# {'name': 'なぞって冒険！きゅるるんくまのパズルリンク', 'idx': 6436}
# {'name': 'スタンバイ 仕事もバイトも暮らしにあった選び方', 'idx': 6439}
# {'name': '女の子の憧れが全てつまったTOKYOリアルコーデアプリ - TOPLOG', 'idx': 6440}
# {'name': 'キスまでにしたい10のこと ~ 無料 胸きゅん恋愛小説 放置げーむ ~', 'idx': 6443}
# {'name': '闇金クリッカー', 'idx': 6444}
# {'name': '小牛在线-理财投资神器', 'idx': 6446}
# {'name': '脳トレクロスワード -解けばIQがあがる!?無料パズルゲーム-', 'idx': 6448}
# {'name': '英雄Q传-穿越回合制卡牌手游，梦幻般的剧情，开启3D热血传奇人生', 'idx': 6449}
# {'name': '脱出ゲーム 体育館からの脱出【学校脱出シリーズ5弾】', 'idx': 6450}
# {'name': '全民德州扑克-天天尽享拉斯维加斯之夜', 'idx': 6451}
# {'name': '培训题库', 'idx': 6453}
# {'name': '网娱大师-网吧娱乐大师', 'idx': 6454}
# {'name': '帝国征服者-王者联盟列国纷争', 'idx': 6455}
# {'name': '大江戸ぶらり', 'idx': 6456}
# {'name': '多重人格彼女〜僕の彼女は世界で一番可愛くて、そして狂っている〜', 'idx': 6457}
# {'name': '果冻星连萌-全球极具诱惑益智游戏,好玩的闯关游戏,2016最新休闲益智游戏', 'idx': 6458}
# {'name': '微火车票-查机票订酒店春运特价随行', 'idx': 6459}
# {'name': '霸王英雄传（吕布一统天下，演义三国群英杰传奇）', 'idx': 6460}
# {'name': 'お小遣いアプリ。ポイントをレシートで貯めよう\u3000／\u3000レシポ！', 'idx': 6462}
# {'name': '车轮车友会—汇集养车、洗车、代驾、汽车头条、汽车用品的车友聊天分享之家', 'idx': 6463}
# {'name': '脱出ゲーム\u3000大正ロマン\u3000女記者脱出譚', 'idx': 6464}
# {'name': '奇幻射击2', 'idx': 6466}
# {'name': 'LOCARI(ロカリ)-オトナ女子向けライフスタイル情報アプリ', 'idx': 6467}
# {'name': 'クリアした奴マジ天才', 'idx': 6468}
# {'name': '暇つぶしに人気  脳トレ パズルゲーム\u3000- LINK', 'idx': 6469}
# {'name': '暇なら話そう！誰でも話せて友達も作れる「KoeTomo」', 'idx': 6470}
# {'name': 'ニュース速報と災害地震速報が届くライフライン NewsDigest（ニュースダイジェスト）', 'idx': 6472}
# {'name': '出会い無料のチャット掲示板 LINK', 'idx': 6475}
# {'name': '日曜劇難99.9', 'idx': 6478}
# {'name': 'ホラースポット-ghost spot-意味が分かると怖いマップ', 'idx': 6482}
# {'name': '好车无忧二手车—二手车买卖实体店', 'idx': 6483}
# {'name': '萌店-朋友圈的美味生活', 'idx': 6484}
# {'name': 'デジラアプリ - データ容量のやりくりに', 'idx': 6485}
# {'name': 'FRESH! - ログイン不要・高画質で生放送が見放題', 'idx': 6486}
# {'name': '融360-贷款、信用卡、信用报告', 'idx': 6487}
# {'name': '舞妓ドリル', 'idx': 6489}
# {'name': '作业通-中小学搜题搜作文必备神器', 'idx': 6490}
# {'name': '青藍高校リア充部', 'idx': 6491}
# {'name': '坂本ですが？秘技…フリータイムキラー', 'idx': 6492}
# {'name': '梦幻轩辕', 'idx': 6493}
# {'name': '万年历-日历农历黄历天气', 'idx': 6494}
# {'name': '妙资理财-探索版（安全稳健高收益理财神器  ）', 'idx': 6495}
# {'name': '豪快ショット連発！爽快卓球ゲーム「サァァァ！」', 'idx': 6496}
# {'name': '铁血武林-武侠回合制策略手游', 'idx': 6499}
# {'name': '出会い応援チャットアプリLIKE YOU', 'idx': 6502}
# {'name': 'Black Hole -世の中で最も困難な物理げーむ ぱずる-', 'idx': 6503}
# {'name': '【業界初成長マップ搭載！ねこ育成マト当てパズルRPG】たまねこウォーズ', 'idx': 6504}
# {'name': "Fragment's Note Memories -Fragment's Note公式資料集アプリ-", 'idx': 6505}
# {'name': '無料ゲーム HANABI ON LINE 花火（ハナビ）パズル', 'idx': 6506}
# {'name': 'BiBi娱乐社区 - 好玩的游戏都在这里！', 'idx': 6508}
# {'name': '平安好医生-要健康上平安好医生', 'idx': 6509}
# {'name': 'PP基金理财-灵活存取的高收益金融理财平台', 'idx': 6511}
# {'name': '2代目 Nソウル みそぽん', 'idx': 6513}
# {'name': 'ひとたがやし', 'idx': 6514}
# {'name': '东西战神', 'idx': 6515}
# {'name': '懸賞ソリティア-ギフト券/ギフトコードGETでお小遣いが稼げる定番ソリティアクロンダイク', 'idx': 6516}
# {'name': 'ビッグバン チャット-友達作り ひま友チャット', 'idx': 6517}
# {'name': '信用钱包官方版-用手机号就能贷款', 'idx': 6518}
# {'name': '新大主宰-2016卡牌手游巨作！', 'idx': 6519}
# {'name': 'パチスロ バイオハザード6', 'idx': 6520}
# {'name': '抢火车票 for 12306火车票官网', 'idx': 6523}
# {'name': '爆笑アプリ！人気無料ゲーム kimazui gacha', 'idx': 6526}
# {'name': '戦国乙女〜剣戟に舞う白き剣聖〜西国参戦編', 'idx': 6527}
# {'name': 'トリセツメーカー２\u3000トリセツ診断', 'idx': 6528}
# {'name': 'まぐろ職人（通）', 'idx': 6529}
# {'name': '途牛旅游PRO-订机票酒店，查旅行景点门票', 'idx': 6530}
# {'name': '目の錯覚で性格診断', 'idx': 6531}
# {'name': '僕の彼女が誘拐された。', 'idx': 6532}
# {'name': 'まぐろ投げ！', 'idx': 6534}
# {'name': 'Love Bank-お金ゲーム/恋愛ゲーム/イケメンゲーム/育成ゲーム/タップゲーム/賭けゲーム', 'idx': 6535}
# {'name': 'ピタゴラパブロフ', 'idx': 6536}
# {'name': 'ダニエル！！今はフリーキック中よ！', 'idx': 6537}
# {'name': '女子力たったの５、ゴミずら◇恋愛xイケメン育成+放置げー！無料の育成・恋愛・放置ゲーム～', 'idx': 6538}
# {'name': '大圣捉妖记', 'idx': 6539}
# {'name': '大头儿子天天乐跑-和孩子一起玩的游戏！', 'idx': 6540}
# {'name': '脱出ゲーム 学校の食堂からの脱出', 'idx': 6541}
# {'name': '渡劫-多武器战斗', 'idx': 6542}
# {'name': 'MapFan(マップファン) – 渋滞情報/オービス/オフライン対応の本格カーナビ', 'idx': 6546}
# {'name': 'ハニーズアプリ', 'idx': 6548}
# {'name': '如意夺宝', 'idx': 6549}
# {'name': '謎解き母からのメモ', 'idx': 6550}
# {'name': 'Creema（クリーマ）- ハンドメイドマーケットプレイス', 'idx': 6552}
# {'name': '【実況】今からカレシを葬る #衝撃の実況動画ノベルゲーム', 'idx': 6553}
# {'name': 'モンスト マルチ掲示板 運極 ＆ ガチャ予報 & 攻略情報 for モンスターストライク', 'idx': 6554}
# {'name': '400ステージに挑戦！ばあジャンプ', 'idx': 6557}
# {'name': '果罐Pro-通知中心快捷安全启动插件', 'idx': 6559}
# {'name': 'シュッと描いてポンッ!（シュポン）物理パズル脳トレ', 'idx': 6560}
# {'name': 'HONNE -本音が言える匿名つぶやき&チャットアプリ', 'idx': 6562}
# {'name': 'セブン‐イレブンアプリ', 'idx': 6563}
# {'name': '脳トレ爽快パズル 激ムズ！和のひとふで書き Line', 'idx': 6565}
# {'name': 'わかる！算数 小学４年【下】 for iPad', 'idx': 6566}
# {'name': 'わかる！算数 小学４年【上】 for iPad', 'idx': 6567}
# {'name': 'バーチャル高校野球', 'idx': 6568}
# {'name': '爆速！マルチ募集掲示板 for モンスト', 'idx': 6569}
# {'name': 'ぱちモンパズル〜簡単無料パズルRPGゲーム', 'idx': 6571}
# {'name': '艶が～るプレミアム 女性向け恋愛ゲーム！乙女げーむ', 'idx': 6572}
# {'name': '超特訓！トミックゲーム！！', 'idx': 6574}
# {'name': 'SAMURAI SCHEMA -幕末維新戦記- サムライスキーマ 本格派育成放置ゲーム', 'idx': 6575}
# {'name': '花火撮影 notepad Lite', 'idx': 6576}
# {'name': 'NOW直播—腾讯旗下全民直播平台', 'idx': 6577}
# {'name': 'ATOK -日本語入力キーボード', 'idx': 6578}
# {'name': '全国一斉性格テストDX', 'idx': 6579}
# {'name': '盗墓之王-寻龙秘事', 'idx': 6580}
# {'name': 'ニート勇者３ -闇の側の者たち- 無料ロールプレイングゲームRPG', 'idx': 6584}
# {'name': 'もこうもこもこ', 'idx': 6585}
# {'name': '美柚经期助手(专业版)-月经·生理期预测，还能备孕育儿', 'idx': 6586}
# {'name': '愛しのショコラティエ いけめん恋愛ゲーム・乙女げーむ女性向け人気', 'idx': 6587}
# {'name': '斗斗大冒险之我爱斗斗堂-官方正版4v4竞技抛物线手游', 'idx': 6588}
# {'name': '式姫４コマ 其之四', 'idx': 6591}
# {'name': 'テレビ視聴', 'idx': 6592}
# {'name': 'もじさがし', 'idx': 6594}
# {'name': '彩库宝典-【官方版】', 'idx': 6595}
# {'name': '口袋电玩-经典街机游戏真人秀版•玩转全民疯狂欢乐火拼炸诈扎金花送斗牛牛麻将VIP', 'idx': 6596}
# {'name': 'e袋洗-新用户领20元优惠券，20分钟上门取送', 'idx': 6603}
# {'name': '脱出ゲーム 気まぐれカフェの謎解きタイム', 'idx': 6604}
# {'name': 'ぷかぷか', 'idx': 6605}
# {'name': '最後の英単語学習！マジタン', 'idx': 6607}
# {'name': '星になったカイロくん', 'idx': 6608}
# {'name': 'Love Bank -お金ゲーム/恋愛ゲーム/美少女ゲーム/育成ゲーム/タップゲーム/賭けゲーム', 'idx': 6609}
# {'name': '【完全無料】ソク出会える！ひみつフレ探し掲示板', 'idx': 6610}
# {'name': '闪瘦-健康减肥瘦身', 'idx': 6611}
# {'name': 'SKK アクション ブロック崩し', 'idx': 6612}
# {'name': 'Ticket Camp - フリマよりも安心で簡単なチケットアプリ', 'idx': 6615}
# {'name': '无双小师妹-登录送橙将', 'idx': 6616}
# {'name': '冒険ディグディグ（ドット絵ｘ放置ｘ冒険RPG）', 'idx': 6618}
# {'name': '成金電鉄-超ハマる放置系ゲーム', 'idx': 6619}
# {'name': '歌手発掘 動画投稿アプリ  カラオケ！sing!  App Star', 'idx': 6620}
# {'name': '世界邦行程大师-出国自由行定制专家', 'idx': 6621}
# {'name': '妙健康-健康自测管家', 'idx': 6622}
# {'name': '大空ヘクタール農園', 'idx': 6623}
# {'name': 'FUNDO［ファンドゥ］- 話題のネタを毎日更新！無料ニュースメディア', 'idx': 6627}
# {'name': 'JR東日本アプリ', 'idx': 6628}
# {'name': '咪咕视频-电视剧综艺直播', 'idx': 6630}
# {'name': '多融理财(Pro版)-12%高收益理财投资平台', 'idx': 6631}
# {'name': 'Horror Story 2016\u3000こわい話', 'idx': 6632}
# {'name': '美男美女診断', 'idx': 6633}
# {'name': '青藍高校ヒモ部', 'idx': 6635}
# {'name': '陌爱神器-不闲聊！陌生人快速约见面平台', 'idx': 6636}
# {'name': '激ムズ！和のひとふで書き！online', 'idx': 6638}
# {'name': 'それゆけ！ヤンキッキー', 'idx': 6639}
# {'name': '陌爱-最in全民交友神器！同城寂陌陌生帅哥美女视频聊天约会平台', 'idx': 6640}
# {'name': '开心扫雷-根本停不下来的创新玩法', 'idx': 6641}
# {'name': '高清影视-大片免费天天看', 'idx': 6642}
# {'name': 'そら案内', 'idx': 6643}
# {'name': 'ダイエット女子が痩せた魔法のアプリ-食事・運動・美容＠DIET', 'idx': 6644}
# {'name': 'ゴミカレ!!', 'idx': 6646}
# {'name': '輪ゴムでシュート！ - 無料で遊べるミニゲーム', 'idx': 6647}
# {'name': 'レアジョブ瞬間中学英単語 | リスニングやTOEICの基礎学力にも', 'idx': 6649}
# {'name': '電車パズル ツメツメ - 通勤時間にピッタリ! 脳トレパズル', 'idx': 6650}
# {'name': 'カテエネ×Shufoo！', 'idx': 6652}
# {'name': '妖怪别跑', 'idx': 6654}
# {'name': 'ゴールできたら神！！2', 'idx': 6656}
# {'name': '艺龙旅行Pro-酒店预订专家', 'idx': 6658}
# {'name': '魔女の泉', 'idx': 6659}
# {'name': 'スカッと！脳トレ！ピッといん〜頭がよくなるブロックパズルゲーム〜', 'idx': 6660}
# {'name': '大学生のための時間割', 'idx': 6662}
# {'name': 'パチスロ モンスターハンター 月下雷鳴', 'idx': 6663}
# {'name': 'オービス警報 - オービス/速度取締り&渋滞', 'idx': 6664}
# {'name': '【完全無料】おとな専用！出会い掲示板', 'idx': 6665}
# {'name': 'モンスターマスターX【オンライン対戦型RPG（ロールプレイング・ゲーム）】', 'idx': 6667}
# {'name': 'G1牧場ステークス', 'idx': 6671}
# {'name': 'minimo（ミニモ）/サロン予約', 'idx': 6672}
# {'name': 'スーパーストリートファイターIV パチスロエディション', 'idx': 6673}
# {'name': 'PIXUSかんたん年賀状', 'idx': 6675}
# {'name': 'BLEACH 公式連載アプリ〜BLEACHの漫画が毎週１巻読めるアプリ〜', 'idx': 6676}
# {'name': '謎解き[緋色探偵社と100の推理]メッセージアプリ風ノベルゲーム', 'idx': 6677}
# {'name': '【謎解き推理】意味が分かると怖い話-この怖い話を謎解き、怪談を読み解けるか…', 'idx': 6678}
# {'name': 'フラッシュワード〜光速瞬間記憶脳トレクイズ〜', 'idx': 6679}
# {'name': '合戦!!にんじゃ村', 'idx': 6681}
# {'name': 'プログレッシブ ロシア語辞典', 'idx': 6683}
# {'name': '[GP]SLOT魔法少女まどかマギカ(パチスロゲーム)', 'idx': 6684}
# {'name': 'にゃんちゅう', 'idx': 6685}
# {'name': 'スナイパイ72', 'idx': 6686}
# {'name': '戦国乙女〜剣戟に舞う白き剣聖〜', 'idx': 6687}
# {'name': 'RAMP-光を灯す孤独な物語- #無料アクションゲーム', 'idx': 6688}
# {'name': '[GP]ハナハナホウオウ-30(パチスロゲーム)', 'idx': 6689}
# {'name': '広告ブロッカー（ウェブ画面上の広告をブロックする最強アプリ)', 'idx': 6690}
# {'name': '下ヨシ子の「２０１６年\u3000あなたの流生命」', 'idx': 6692}
# {'name': 'You勇者 -HIKAKINとSEIKIN(ヒカキンとセイキン)と無料ロールプレイング', 'idx': 6693}
# {'name': 'ViRATES[バイレーツ]-面白ネタまとめの決定版！', 'idx': 6694}
# {'name': '逆战仙魔 大圣萌仙全民跨服千人即时PK', 'idx': 6697}
# {'name': '魔灵觉醒（王者归来）- 3D新职业魔剑士降临', 'idx': 6699}
# {'name': 'Test your color IQ！カラーIQ診断テスト', 'idx': 6702}
# {'name': 'お解きなさい！', 'idx': 6703}
# {'name': 'スマイルパーク 〜らくらく放置系遊園地ゲーム〜', 'idx': 6704}
# {'name': '戦国乙女2～深淵に輝く気高き将星～', 'idx': 6707}
# {'name': '筆姫 - オシャレなグリーティングカード SNS投稿 自宅印刷もOK', 'idx': 6709}
# {'name': '恋愛タップコミュニケーションゲーム 週刊マイメイド', 'idx': 6710}
# {'name': '東京時層地図 for iPad', 'idx': 6711}
# {'name': 'ゲッターズ飯田の占い', 'idx': 6712}
# {'name': 'Ｘ:15秒の人気 アクション ゲーム', 'idx': 6713}
# {'name': '誰にもバレない！[秘密のアルバム]\u3000無料で写真をロック！', 'idx': 6714}
# {'name': 'まるみえ！性教育ふしぎ発見-クイズで学ぶ保健体育', 'idx': 6716}
# {'name': '頭の回転をはやくする！脳トレ！Blackhole', 'idx': 6717}
# {'name': '心霊たんち機 Plus', 'idx': 6718}
# {'name': '心がラクになる後ろ向き名言100選', 'idx': 6719}
# {'name': 'スタバで呪文', 'idx': 6720}
# {'name': '意味が分かると怖い話-この意味怖を謎解きできるか…【謎解き意味怖】', 'idx': 6721}
# {'name': 'シカクイズ -暇つぶしマンガアニメ映画クイズ-暇つぶしに最適', 'idx': 6722}
# {'name': '赤ペン 提出カメラ', 'idx': 6723}
# {'name': '極寒スライダー', 'idx': 6726}
# {'name': '【脱出ゲーム】絶対に最後までプレイしないで 〜謎解き＆ブロックパズル〜', 'idx': 6729}
# {'name': 'クリスマスミッケ/脱出ゲーム感覚の絵探しパズルゲーム', 'idx': 6730}
# {'name': '激ムズ！和のひとふで書き！ 〜頭をつかう脳トレパズルゲーム〜', 'idx': 6731}
# {'name': 'ゲオ\u3000クーポンが貰える！ゲーム予約もできる！', 'idx': 6732}
# {'name': '飞凡--智慧新生活', 'idx': 6733}
# {'name': 'PROF - 共通点で楽しむSNS', 'idx': 6734}
# {'name': '觉醒吧数码兽-被选召的孩子  超人气动漫  回合制卡牌策略养成', 'idx': 6735}
# {'name': '小学館 オックスフォード 英語コロケーション辞典', 'idx': 6737}
# {'name': 'スーパーブラックジャック2', 'idx': 6739}
# {'name': '海鮮!!すし街道', 'idx': 6740}
# {'name': '丸亀製麺', 'idx': 6741}
# {'name': 'ＣＲスーパー海物語ＩＮ沖縄４', 'idx': 6742}
# {'name': '热血超人-二次元卡牌游戏', 'idx': 6743}
# {'name': '脱出ゲーム\u3000海底神殿からの脱出', 'idx': 6744}
# {'name': '你我贷理财-P2P理财管家', 'idx': 6745}
# {'name': 'パチスロ ガールズ＆パンツァー', 'idx': 6747}
# {'name': '全民打金币——爽快的正版放置手游', 'idx': 6748}
# {'name': '森林舞会-3d画面刺激的娱乐城游戏', 'idx': 6749}
# {'name': '你我贷理财-基金理财工具', 'idx': 6750}
# {'name': '謎トレ 謎解き脳トレーニング', 'idx': 6751}
# {'name': '钱妈妈理财-国企投资有保障的金融理财产品！', 'idx': 6752}
# {'name': '大人がハマる脳トレ！ぷるるん～頭が良くなる一筆書きパズル～', 'idx': 6754}
# {'name': 'QRコードリーダー for iPhone', 'idx': 6755}
# {'name': '肌年齢診断', 'idx': 6756}
# {'name': '自らデッドボール', 'idx': 6758}
# {'name': '洋葱圈—正经人的不正经聊天工具', 'idx': 6759}
# {'name': '飞刀传奇-动作武侠热血江湖即时PK传奇（登录爆金装）', 'idx': 6760}
# {'name': 'パチスロ デビル メイ クライ クロス', 'idx': 6761}
# {'name': 'ガールズちゃんねる - 女子のニュースとガールズトーク', 'idx': 6762}
# {'name': '英熟語ターゲット1000（4訂版）', 'idx': 6763}
# {'name': '【マイナビバイト大学生版】大学生のバイト探し・アルバイト求人', 'idx': 6764}
# {'name': '兜町アナリストがお伝えする「兜予報」（無料）', 'idx': 6766}
# {'name': 'ドリブルの達人', 'idx': 6769}
# {'name': '剑客情缘-高爆率高掉落天天疯玩', 'idx': 6770}
# {'name': '【放置】勇者改名 ～「ふざけた名前つけやがって！」', 'idx': 6771}
# {'name': '現金製造ロボ -毎日コツコツ3万円稼ぐ-', 'idx': 6772}
# {'name': '出会い系無料で遊べるsnsアプリ内緒チャットトーク', 'idx': 6773}
# {'name': '鬼吹灯昆仑神宫 - 年兽袭来', 'idx': 6774}
# {'name': 'スッキリ謎解きゲーム！！', 'idx': 6775}
# {'name': 'えほう - 最強の恵方コンパス', 'idx': 6776}
# {'name': 'Clash of Richers 3 （城市富翁3）', 'idx': 6777}
# {'name': '借金勇者~そして完済へ…', 'idx': 6778}
# {'name': 'BLOCK(ブロック) -ぼくの箱庭【3D】-', 'idx': 6781}
# {'name': '问仙奇遇-新玩法新套装嗨到爆', 'idx': 6785}
# {'name': '心の美男美女診断', 'idx': 6786}
# {'name': '動画英文法2700', 'idx': 6787}
# {'name': 'TAP BRAIN - 1日5分の計算で頭が良くなるゲーム', 'idx': 6788}
# {'name': '地元の掲示板「ジモティー」地元でカンタン！フリマよりもお得！', 'idx': 6789}
# {'name': 'モンスト覇者の塔マルチ掲示板 for モンスターストライク', 'idx': 6792}
# {'name': 'ケンタッキーフライドチキン\u3000公式アプリ', 'idx': 6793}
# {'name': '君にはクリアできませんよ', 'idx': 6795}
# {'name': 'おわかりいただけただろうか心霊写真で最恐ホラー体験', 'idx': 6796}
# {'name': 'こっち見んなwww', 'idx': 6797}
# {'name': 'ねこあわせ。', 'idx': 6798}
# {'name': '烈焰王座-称霸魔法帝国的策略游戏', 'idx': 6800}
# {'name': '激突!!10円玉ドッカンバトル -最強AIに勝てる？-', 'idx': 6801}
# {'name': '脱出ゲーム 学校の七不思議 -恐怖からの脱出-', 'idx': 6802}
# {'name': 'Round1 お得なクーポン毎週配信！', 'idx': 6803}
# {'name': '金钱谷软件-活期手机金融投资理财平台!', 'idx': 6804}
# {'name': 'プチ・ロワイヤル仏和辞典（第4版）・和仏辞典（第3版）', 'idx': 6805}
# {'name': '出会い秘密チャット - 相席 出会い系チャット', 'idx': 6807}
# {'name': 'CROSS -よけてすすむ爽快アクション-', 'idx': 6810}
# {'name': '秘密の関係はじめました メッセージ風恋愛ゲーム', 'idx': 6811}
# {'name': '死亡フラグがたちました！！【ノベルゲーム型あるある謎解きアドベンチャー】', 'idx': 6816}
# {'name': '零钱夺宝pro-新手99元红包助你1元购', 'idx': 6817}
# {'name': 'ハマる脳とれ ぱずる!!PITTARI～子供も楽しめる脳とれ ぱずるげーむ～', 'idx': 6819}
# {'name': '飛べないロボはただの... ～無料アクションRPGゲーム～', 'idx': 6820}
# {'name': 'ピンポンファイター - 卓球王にオレはなるっ！！', 'idx': 6821}
# {'name': '一起捕鱼 - 欢乐街机电玩城', 'idx': 6822}
# {'name': '机で卓球', 'idx': 6823}
# {'name': '開園ピクセル牧場', 'idx': 6824}
# {'name': '斗地主·大全-2017年最受欢迎的精品棋牌游戏合集', 'idx': 6825}
# {'name': 'サクサクチェッカー 最適化  -  iChecker', 'idx': 6826}
# {'name': 'ママはストーカー', 'idx': 6828}
# {'name': 'Übungen für einen starken Rücken – GEO WISSEN GESUNDHEIT', 'idx': 6829}
# {'name': '易经全集-[有声读物]', 'idx': 6830}
# {'name': 'バーチャル恵方巻【節分・恵方コンパス・方位】', 'idx': 6832}
# {'name': 'My Diary - 你的名字非官方', 'idx': 6833}
# {'name': 'タップモンスター◆タップだけの簡単本格RPG/タプモン', 'idx': 6835}
# {'name': 'Brain Block -脳トレ分解パズル-', 'idx': 6836}
# {'name': '脳トレ！パターンキューブ', 'idx': 6837}
# {'name': 'ぼくのボッタクリBAR2 -全国制覇篇-', 'idx': 6838}
# {'name': 'プリンセスクローゼット 女性向け恋愛ゲーム！乙女げーむ', 'idx': 6839}
# {'name': '恋愛ゴシップ 女性向け恋愛ゲーム！乙女げーむ', 'idx': 6842}
# {'name': '尚品网 - 全球精品高端时尚购物网站', 'idx': 6843}
# {'name': 'ロボはつらいよ。～フルボッコタワー～アクション育成強化ゲーム！', 'idx': 6845}
# {'name': 'デビルサバイバー２ 最後の７日間', 'idx': 6848}
# {'name': '大人の出会いチャット  - 出会い系 アプリ', 'idx': 6849}
# {'name': '星之轨迹-好玩的手游角色扮演网游新游戏', 'idx': 6851}
# {'name': '食べないと死ぬ 3', 'idx': 6852}
# {'name': 'Boooom!! -たった1発で爆破できますか？-', 'idx': 6853}
# {'name': '激ムズ！お前、脱出できんの？～反射神経アクションゲーム～', 'idx': 6856}
# {'name': '意味が分かると怖い話【意味怖】-この怖い話の意味が分かるか…', 'idx': 6857}
# {'name': 'おかず甲子園', 'idx': 6858}
# {'name': '絶対に笑える話\u3000腹筋崩壊の笑える話', 'idx': 6860}
# {'name': '時計仕掛けの彼女 /明日なんて来なきゃいいのにね', 'idx': 6861}
# {'name': 'マンガモンスター \u3000無料マンガ/無料本/人気マンガ', 'idx': 6862}
# {'name': '妹型杀器', 'idx': 6865}
# {'name': '武神战纪OL-热血三国志国战手游', 'idx': 6867}
# {'name': '激ムズ！にゃんコプター', 'idx': 6868}
# {'name': '謎解きあの人からメール', 'idx': 6869}
# {'name': '东方财富网领先版-财经资讯&股票开户', 'idx': 6870}
# {'name': '暗黑屠魔者2（唉哟-还不错哦）', 'idx': 6871}
# {'name': 'エジコイ！〜エジプト神と恋しよっ〜', 'idx': 6872}
# {'name': '剑雨奇缘-万人同屏PK,唯美风仙侠', 'idx': 6873}
# {'name': 'PINGPONG（ピンポン）- 君の反射神経Lvはいくつ？', 'idx': 6874}
# {'name': '椅子ドンVR~一ノ宮英介 編~', 'idx': 6875}
# {'name': 'マンガきゅんと‐漫画が全話読み放題の少女まんがアプリ', 'idx': 6877}
# {'name': 'ダイエットやメイク、ネイルのコスメ情報 - シェリル', 'idx': 6879}
# {'name': '国金宝理财-15%年化收益的金融投资赚钱软件', 'idx': 6880}
# {'name': '女性向けまとめ読みアプリ - pool（プール）-', 'idx': 6881}
# {'name': 'イケメン革命◆アリスと恋の魔法 恋愛ゲーム', 'idx': 6882}
# {'name': 'ライブチャット、ビデオチャット通話が楽しめる！ ライブでゴーゴー', 'idx': 6884}
# {'name': '百盈足球-专业足篮比分赛事预测', 'idx': 6885}
# {'name': 'ねこめし屋 -マンガも読めるネコゲーム料理店経営の無料育成シュミレーション-', 'idx': 6886}
# {'name': 'Please,Dad. I wanna live.\u3000おとうさん、おねがい。わたし生きたいよ。', 'idx': 6887}
# {'name': 'ひとほろぼし', 'idx': 6890}
# {'name': 'ST channel ［エスティーチャンネル］- 雑誌『セブンティーン』公式アプリ', 'idx': 6891}
# {'name': 'ごちうさアラーム～シャロ編～', 'idx': 6892}
# {'name': '战歌联萌-新英雄登场 惊喜嘉年华', 'idx': 6894}
# {'name': 'テニスクラブ物語', 'idx': 6895}
# {'name': '不良西游-神魔悟空大战篇', 'idx': 6897}
# {'name': 'ScaryStory in Japan 怖い話し無料', 'idx': 6900}
# {'name': '-The 穴通し3D- 君の記憶力x反射神経を問う! ～Mr.CURVEからの挑戦状 ～', 'idx': 6903}
# {'name': '【殺人現場へようこそ】推理サスペンス劇場/謎解き大人の脳トレゲーム', 'idx': 6904}
# {'name': '鳥として生きた男\u3000その壮絶な人生', 'idx': 6906}
# {'name': 'キクタン 【Advanced】 6000 ～聞いて覚える英単語～(アルク)', 'idx': 6907}
# {'name': '全民夺宝(官方)', 'idx': 6909}
# {'name': '大盛グルメ食堂', 'idx': 6910}
# {'name': 'MineSweeper\u3000マインスイーパ無料', 'idx': 6911}
# {'name': '秒速で1億円 貢ぐ男\u3000～美女キャラ集結！from ギャングロード JOKER～', 'idx': 6912}
# {'name': '学年ビリのギャルが今さら受験してみた', 'idx': 6913}
# {'name': '吕布帮帮忙-三国策略卡牌，指间微操轻松畅玩', 'idx': 6914}
# {'name': 'キクタンTOEIC(R) Test Score 600 ～聞いて覚える英単語～(アルク)', 'idx': 6915}
# {'name': '通信量チェッカー', 'idx': 6917}
# {'name': '脱出ゲーム\u3000カリスマブラザーズのワクワク女子寮脱出大作戦', 'idx': 6919}
# {'name': '剑倚手游', 'idx': 6924}
# {'name': '電球でテニスしてみた-無料で遊べるミニゲーム', 'idx': 6925}
# {'name': '箱庭シティ鉄道', 'idx': 6926}
# {'name': '平安证券', 'idx': 6927}
# {'name': '謎解き窓ガラスの跡', 'idx': 6928}
# {'name': 'モンスト全国マルチ掲示板 for モンスターストライク！〜タスカンと運極が作れるアプリ〜', 'idx': 6930}
# {'name': '恋する幽霊-カレシ、死んでます。-', 'idx': 6931}
# {'name': '人気の動画まとめてみた。"for YouTube"', 'idx': 6932}
# {'name': 'キクタン  【Basic】  4000 ～聞いて覚える英単語～(アルク)', 'idx': 6933}
# {'name': 'キクタン 【Super】 12000 ～聞いて覚える英単語～(アルク)', 'idx': 6936}
# {'name': '香哈菜谱-最专业的家常菜谱大全 无广告版', 'idx': 6937}
# {'name': '五目並べ - オンライン対戦搭載！', 'idx': 6939}
# {'name': '王权之战-帝国时代皇室争霸！', 'idx': 6940}
# {'name': 'アニメスタジオ物語', 'idx': 6942}
# {'name': '[GP]パチスロ デビル メイ クライ クロス(パチスロゲーム)', 'idx': 6943}
# {'name': '冒険ダンジョン村', 'idx': 6944}
# {'name': 'ほぼ無理ゲー', 'idx': 6945}
# {'name': 'CUBE 360°\u3000～想像力×知能×反射神経～', 'idx': 6946}
# {'name': '勘違い探し（俺のこと・・・）', 'idx': 6948}
# {'name': '凤凰新闻(专业版)-有料的军事新闻、娱乐短视频', 'idx': 6949}
# {'name': 'スシロー', 'idx': 6950}
# {'name': '大人のためのかわいいお買い物アプリSUCRESIA(シュクレシア）', 'idx': 6952}
# {'name': '机甲无双－燃即正义 殿堂级战斗手游', 'idx': 6953}
# {'name': '完全犯罪クラブ', 'idx': 6954}
# {'name': 'こち亀 公式連載アプリ〜こち亀の漫画が読めるアプリ〜', 'idx': 6955}
# {'name': '投资乐VIP-白银黄金贵金属理财投资', 'idx': 6956}
# {'name': '脱出ゲーム KA-MA-KU-RA', 'idx': 6957}
# {'name': '恵方コンパス！【恵方巻を食べる方角がすぐ探せる！】', 'idx': 6958}
# {'name': 'ヨドバシ', 'idx': 6959}
# {'name': 'オービスガイド - 新型オービス&ネズミ捕り&検問', 'idx': 6960}
# {'name': '万年历-农历黄历日历天气', 'idx': 6961}
# {'name': '777游戏厅-2017超人气掌上游戏厅', 'idx': 6963}
# {'name': '脱出ゲーム Toilet', 'idx': 6964}
# {'name': '【負けるが勝ち？】少数派に入れば勝利の7Beget', 'idx': 6967}
# {'name': '脱出ゲーム 心霊学校からの脱出', 'idx': 6968}
# {'name': 'ごちうさアラーム\u3000～ココア編～', 'idx': 6970}
# {'name': '彼女の涙が僕を人間にした', 'idx': 6971}
# {'name': '壊して！無限ドリルランド', 'idx': 6976}
# {'name': '脱出ゲーム Oden', 'idx': 6978}
# {'name': '[GP]アナザーゴッドハーデス-奪われたZEUSver.-(パチスロゲーム)', 'idx': 6980}
# {'name': 'おやじが跳ぶ', 'idx': 6981}
# {'name': 'ナイトメアハーレム 女性向け恋愛ゲーム！乙女げーむ', 'idx': 6982}
# {'name': 'キンニクエスト 筋肉と筋肉と筋肉と呪われし筋肉', 'idx': 6983}
# {'name': 'モンストマルチ掲示板 〜 The BEST 〜 for モンスターストライク', 'idx': 6985}
# {'name': '战车世纪·经典FC重装机兵归来', 'idx': 6986}
# {'name': '四角い頭を丸くする2', 'idx': 6988}
# {'name': 'Yahoo!防災速報 - 地震や豪雨など災害情報をいち早く通知', 'idx': 6989}
# {'name': '英単語ターゲット1900（5訂版）', 'idx': 6990}
# {'name': '下ヨシ子の「２０１７年\u3000あなたの流生命」', 'idx': 6991}
# {'name': '性格美男美女診断２', 'idx': 6994}
# {'name': 'Think in Japanese (Original name:ひとりごと英語)', 'idx': 6995}
# {'name': '【ひっぱりパズル】ズキュ〜〜〜〜ン！', 'idx': 6996}
# {'name': '完全心理プロファイルX', 'idx': 6997}
# {'name': '秒で100億円', 'idx': 6999}
# {'name': '恵方コンパス.', 'idx': 7000}
# {'name': '古墓仙缘-古装恋爱修仙手游', 'idx': 7002}
# {'name': '番茄电玩城', 'idx': 7003}
# {'name': '大人の脳トレ！ぴたぽん #頭が良くなる #快感ハメコミパズル', 'idx': 7005}
# {'name': '笑ったら負け', 'idx': 7007}
# {'name': '「宅建士」過去問題《受験用》', 'idx': 7008}
# {'name': '物理パズル:flower（フラワー）', 'idx': 7010}
# {'name': '俺が浮気した時の話、聞く？ 男女の修羅場の話まとめ', 'idx': 7011}
# {'name': '轩辕剑叁外传之天之痕-正版经典仙侠授权', 'idx': 7012}
# {'name': 'ジーユー', 'idx': 7013}
# {'name': '主播炸金花', 'idx': 7015}
# {'name': '謝罪会見', 'idx': 7016}
# {'name': '早くトイレに行きたい', 'idx': 7018}
# {'name': '僕の魔球打てるの？', 'idx': 7020}
# {'name': 'アウト～まさか浮気してないよね？～【恋愛不倫探しゲーム】', 'idx': 7022}
# {'name': '애드픽 - 인플루언서가 되어 의미있는 수익을 올리세요!', 'idx': 7023}
# {'name': '[GP]パチスロ ヱヴァンゲリヲン〜決意の刻〜(パチスロゲーム)', 'idx': 7026}
# {'name': 'メンタルリープのアプリ：ワンダーウィーク（旧：ワンダーウィークス）', 'idx': 7027}
# {'name': 'がんばれルルロロ！かさねてブロック', 'idx': 7030}
# {'name': 'なっとう-人気の納豆育成ゲーム-', 'idx': 7031}
# {'name': '全国マルチ掲示板 for モンスト！〜タスカンと運極ができるアプリ〜', 'idx': 7032}
# {'name': '一筆書きゲーム！無料パズルで脳トレしよう！ by だーぱん', 'idx': 7033}
# {'name': 'センバツLIVE!2017／第89回選抜高校野球大会公式アプリ', 'idx': 7034}
# {'name': '新・血液型テスト', 'idx': 7035}
# {'name': 'ジョナサンアプリ\u3000お得なクーポンが使える便利なアプリ', 'idx': 7037}
# {'name': 'パチスロ黄門ちゃま 喝', 'idx': 7038}
# {'name': '罪と罰2 -犯人は誰だ!?- 謎解き推理ミステリーサスペンス', 'idx': 7041}
# {'name': 'AKUMA大戦 -悪魔を合体召喚して魔王を育成する放置ゲーム-', 'idx': 7042}
# {'name': '心动K歌恋爱季-让我们一起唱歌听歌恋爱吧', 'idx': 7045}
# {'name': 'さすゆう -さすがは勇者様です-無料放置系お手軽RPG!!', 'idx': 7046}
# {'name': '30秒マン-これクリアできるやついる？-', 'idx': 7047}
# {'name': '开挂江湖-Q版武侠挂机', 'idx': 7049}
# {'name': '犯人は僕です。－謎解き×探索ノベルゲーム－', 'idx': 7050}
# {'name': 'js体育资讯', 'idx': 7051}
# {'name': '每日红包', 'idx': 7052}
# {'name': '激Jパチスロ 2027', 'idx': 7053}
# {'name': 'ビルホッピング', 'idx': 7054}
# {'name': '犯人は僕です。～露天風呂編～', 'idx': 7055}
# {'name': '紫马财行理财精英版—安全可靠的投资理财平台', 'idx': 7059}
# {'name': 'SPI言語 【Study Pro】', 'idx': 7060}
# {'name': 'みんなの性格検定', 'idx': 7061}
# {'name': 'テトリマン', 'idx': 7062}
# {'name': 'サクッとスッキリ！ラインナンバー！', 'idx': 7064}
# {'name': '僕の妹が死んだ。', 'idx': 7065}
# {'name': 'ゲスの極み!パリピを探せ!!笑える・ハマる間違い探しゲーム（意外と難問）', 'idx': 7066}
# {'name': '封神榜（洪荒西游英杰传奇）', 'idx': 7067}
# {'name': 'ピッタリあわせて！脳トレcube', 'idx': 7068}
# {'name': 'キモゲーいや、きも毛ー', 'idx': 7070}
# {'name': '出会うカメ', 'idx': 7071}
# {'name': 'アイドルの姫\u3000-わたしの青春マテリアル-', 'idx': 7075}
# {'name': 'ゲーム攻略「SGGP」掲示板、SNSな友達出会い', 'idx': 7077}
# {'name': '意味が分かると怖い話-この怖い話の意味分かる？【意味怖】', 'idx': 7078}
# {'name': 'TOEIC®テストリスニング360問', 'idx': 7079}
# {'name': '诛妖奇遇-3D仙侠恋爱网游年度巨献(浪漫回合)', 'idx': 7080}
# {'name': '泰坦来袭-热血英雄燃爆部落争霸之战', 'idx': 7081}
# {'name': '蒼の彼方のフォーリズム‐ETERNAL SKY-', 'idx': 7082}
# {'name': '江湖侠客录－武侠迷必玩单机手游', 'idx': 7086}
# {'name': '巨商传奇', 'idx': 7087}
# {'name': 'ナビタイム ドライブサポーター - NAVITIMEのカーナビアプリ', 'idx': 7093}
# {'name': '琅琊天下 - 原著改编单机武侠角色扮演RPG', 'idx': 7094}
# {'name': 'FixYou-無料でチャットトークができるSNSマッチングアプリ', 'idx': 7096}
# {'name': '花しらべ 花認識/花検索', 'idx': 7097}
# {'name': '挂机三国-最强挂机游戏', 'idx': 7098}
# {'name': '修仙幻想-经典萌系回合', 'idx': 7099}
# {'name': '逍遥修仙-掌上360度自由视角经典仙侠动作游戏', 'idx': 7100}
# {'name': '天神决-创新仙侠手游', 'idx': 7101}
# {'name': '修仙侠侣-正统中国风仙侠新作', 'idx': 7102}
# {'name': '胜者为王-多人同时在线PK传奇类手机网游！', 'idx': 7103}
# {'name': 'ネイティブ1000人と作った英会話～日常英会話編～', 'idx': 7105}
# {'name': '懸賞ソリティア-懸賞応募でギフト券が稼げるソリティア！-無料懸賞ゲーム', 'idx': 7107}
# {'name': '别动我学姐-校园格斗巅峰之作', 'idx': 7109}
# {'name': 'マイにゃんカフェ', 'idx': 7111}
# {'name': 'うねうね糸', 'idx': 7113}
# {'name': 'リア充撲滅RUN', 'idx': 7114}
# {'name': '仙侠剑客—大型3D精品ARPG动作神作', 'idx': 7115}
# {'name': '競馬予想 アプリ！馬券予想で収支アップ！競馬 jra 攻略！', 'idx': 7116}
# {'name': 'どうして私じゃダメなの？', 'idx': 7119}
# {'name': '出会い系アプリ i-Mail（アイメール）', 'idx': 7120}
# {'name': 'コンテンツブロッカー280 / 最高の広告ブロック 280blocker', 'idx': 7121}
# {'name': 'オトナの教科書〜学校じゃ教わらない裏教育クイズ(画像付き)〜', 'idx': 7122}
# {'name': 'ねこげーむ~ねこ騎士ポチ~簡単で人気の猫ゲーム~基本無料', 'idx': 7123}
# {'name': '大人には解けない問題', 'idx': 7124}
# {'name': '妖萌战姬HD - 日系二次元萌娘卡牌手游', 'idx': 7125}
# {'name': 'TOEIC®テスト文法640問1', 'idx': 7127}
# {'name': '僕の彼女が成仏するまで', 'idx': 7128}
# {'name': '霸王卧龙传奇（全新转职系统，60种职业供你选择）', 'idx': 7129}
# {'name': '謎解き赤い封筒', 'idx': 7131}
# {'name': 'GETだぜ！じゃねーよｗ for ポケモン', 'idx': 7132}
# {'name': '同城爱约会-单身男女约会神器', 'idx': 7134}
# {'name': '最佳足球经理(非彩票)', 'idx': 7139}
# {'name': '誰ガ為ノ世界~悲しみと始まりのユグドラシル~', 'idx': 7140}
# {'name': 'へびでか〜へび刑事純情物語〜【放置ゲーム】', 'idx': 7142}
# {'name': '东方头条（探索版）订阅分享感兴趣的新闻和搞笑视频', 'idx': 7143}
# {'name': '脳トレ物理パズル【キタコレ！】～IQの限界に挑めるパズルゲーム～ktkr', 'idx': 7145}
# {'name': '金のフレーズ 〜「新TOEIC®TEST 出る単特急 金のフレーズ」収録 〜', 'idx': 7146}
# {'name': '山手線走ってみた。', 'idx': 7147}
# {'name': '无敌战舰-经典策略海战巅峰对决', 'idx': 7149}
# {'name': 'ジェスチャー当て', 'idx': 7151}
# {'name': 'スピードOnline トランプゲーム', 'idx': 7152}
# {'name': 'まっぷるリンク - 旅行ガイドを丸ごとアプリで持ち歩き', 'idx': 7153}
# {'name': 'SPI非言語 【Study Pro】', 'idx': 7155}
# {'name': 'こだわりラーメン館', 'idx': 7156}
# {'name': '【意味笑】意味が分かると面白い話-謎解き2ch系推理ゲーム', 'idx': 7157}
# {'name': '疯狂百宝箱', 'idx': 7158}
# {'name': 'RPG 偽りの物語 / ドット絵ロールプレイングゲーム', 'idx': 7160}
# {'name': '国美在线 – 新人免费领200元优惠券', 'idx': 7161}
# {'name': '鬼畜三国-红将觉醒', 'idx': 7163}
# {'name': '食べないと死ぬ2', 'idx': 7164}
# {'name': '单读-我们的黄金时代', 'idx': 7165}
# {'name': '脱出ゲーム\u3000ピラミッドからの脱出', 'idx': 7166}
# {'name': '無料で音楽や写真・カメラの裏技アプリ for iPhone7', 'idx': 7167}
# {'name': '自転車ナビ by NAVITIME(ナビタイム) - 自転車のナビができるアプリ', 'idx': 7168}
# {'name': '謎解きロッカーの忘れ物', 'idx': 7169}
# {'name': '大人の納車ゲーム-四角いアタマを丸くする脳トレパズル', 'idx': 7170}
# {'name': 'ねことダンボール', 'idx': 7171}
# {'name': '２ちゃんねる for iPhone', 'idx': 7172}
# {'name': '喔豆-发现世间美味', 'idx': 7173}
# {'name': '梦幻仙途-经典之余又大搞趣味创新（回合制）', 'idx': 7174}
# {'name': '借金あるからギャンブルしてくる', 'idx': 7176}
# {'name': 'ファッション通販 ZOZOTOWN', 'idx': 7177}
# {'name': 'マッチング チャット - マッチング&恋人探しチャット', 'idx': 7178}
# {'name': '理财咖(管家版)-金融投资理财产品多样的手机理财工具!', 'idx': 7181}
# {'name': '弑仙问情', 'idx': 7182}
# {'name': '口袋理财（标准版）-上市公司报喜鸟投资', 'idx': 7183}
# {'name': '友達 恋人探し であい ちゃっと sns -ギャルとも', 'idx': 7185}
# {'name': '【難問謎解き】ねこ神様はクイズ好き？', 'idx': 7186}
# {'name': '【悲報】鬼ヶ島終了のお知らせ\u3000-ゾンビ桃太郎が3Dすぎて鬼やばいwww-', 'idx': 7187}
# {'name': '中学英文法総復習 パターンで覚える 瞬間英文法', 'idx': 7188}
# {'name': 'Brain15 − 脳トレ 無料パズル −', 'idx': 7189}
# {'name': '【謎解き】ヤミすぎ彼女からのメッセージ', 'idx': 7191}
# {'name': 'みんなのお弁当 by クックパッド ~お弁当をレシピ付きで記録・共有~', 'idx': 7194}

# %% [markdown]
# ## Isolating the Free Apps
#
# As we mentioned in the introduction, we only build apps that are free to download and install, and our main source of revenue consists of in-app ads. Our data sets contain both free and non-free apps, and we'll need to isolate only the free apps for our analysis. Below, we isolate the free apps for both our data sets to the `PLATFORM['data_final']` constants.

# %%
# Isolating free ANDROID apps
for app in PLATFORM[0]['data_eng']:
	price = app[7]
	if price == '0':
		PLATFORM[0]['data_final'].append(app)

# Isolating free IOS apps
for app in PLATFORM[1]['data_eng']:
	price = app[4]
	if price == '0.0':
		PLATFORM[1]['data_final'].append(app)

print(f'There are {len(PLATFORM[0]['data_final'])} free Android apps saved for further analysis')
print(f'There are {len(PLATFORM[1]['data_final'])} free iOS apps saved for further analysis')
# Out:
# There are 8861 free Android apps saved for further analysis
# There are 3220 free iOS apps saved for further analysis

# %% [markdown]
# ## Most Common Apps by Genre
#
# ### Part One
#
# As we mentioned in the introduction, our aim is to determine the kinds of apps that are likely to attract more users because our revenue is highly influenced by the number of people using our apps.
#
# To minimize risks and overhead, our validation strategy for an app idea is comprised of three steps:
#
# 1) Build a minimal Android version of the app, and add it to Google Play.
# 2) If the app has a good response from users, we then develop it further.
# 3) If the app is profitable after six months, we also build an iOS version of the app and add it to the App Store.
#
# Because our end goal is to add the app on both the App Store and Google Play, we need to find app profiles that are successful on both markets. For instance, a profile that might work well for both markets might be a productivity app that makes use of gamification.
#
# Let's begin the analysis by getting a sense of the most common genres for each market. For this, we'll build a frequency table for the `prime_genre` column of the App Store data set, and the `Genres` and `Category` columns of the Google Play data set.
#
# ### Part Two
#
# We'll build two functions we can use to analyze the frequency tables:
#
# - One function to generate frequency tables that show percentages
# - Another function that we can use to display the percentages in a descending order

# %%
def freq_table(platform, column_idx):
	platform_dict = define_platform(platform)
	data = platform_dict['data_final']

	output_table = {}
	total = 0

	for row in data:
		total += 1
		criteria = row[column_idx]
		if criteria in output_table:
			output_table[criteria] += 1
		else:
			output_table[criteria] = 1
	
	for key, value in output_table.items():
		output_table[key] = value / total * 100

	return output_table


def display_table(platform, column_idx):
	platform_dict = define_platform(platform)
	table = freq_table(platform, column_idx)
	
	result = []
	for key in table:
		key_value_as_tuple = (table[key], key)
		result.append(key_value_as_tuple)

	result_sorted = sorted(result, reverse=True)

	print(f'The frequency table for {platform_dict['name']} apps by {platform_dict['header'][column_idx].upper()} share:\n')
	for entry in result_sorted:
		print(f'{entry[1]}: {entry[0]}')

# %% [markdown]
# ### Part Three
#
# We start by examining the frequency table for the `prime_genre` column of the App Store data set.

# %%
display_table('ios', -5)
# Out:
# The frequency table for iOS apps by PRIME_GENRE share:
#
# Games: 58.13664596273293
# Entertainment: 7.888198757763975
# Photo & Video: 4.968944099378882
# Education: 3.6645962732919255
# Social Networking: 3.291925465838509
# Shopping: 2.608695652173913
# Utilities: 2.515527950310559
# Sports: 2.142857142857143
# Music: 2.049689440993789
# Health & Fitness: 2.018633540372671
# Productivity: 1.7391304347826086
# Lifestyle: 1.5838509316770186
# News: 1.3354037267080745
# Travel: 1.2422360248447204
# Finance: 1.1180124223602486
# Weather: 0.8695652173913043
# Food & Drink: 0.8074534161490683
# Reference: 0.5590062111801243
# Business: 0.5279503105590062
# Book: 0.43478260869565216
# Navigation: 0.18633540372670807
# Medical: 0.18633540372670807
# Catalogs: 0.12422360248447205

# %% [markdown]
# We can see that among the free English apps, more than a half (58.16%) are games. Entertainment apps are close to 8%, followed by photo and video apps, which are close to 5%. Only 3.66% of the apps are designed for education, followed by social networking apps which amount for 3.29% of the apps in our data set.
#
# The general impression is that App Store (at least the part containing free English apps) is dominated by apps that are designed for fun (games, entertainment, photo and video, social networking, sports, music, etc.), while apps with practical purposes (education, shopping, utilities, productivity, lifestyle, etc.) are more rare. However, the fact that fun apps are the most numerous doesn't also imply that they also have the greatest number of users — the demand might not be the same as the offer.
#
# Let's continue by examining the `Genres` and `Category` columns of the Google Play data set (two columns which seem to be related).

# %%
display_table('and', 1)
# Out:
# The frequency table for Android apps by CATEGORY share:
#
# FAMILY: 18.91434375352669
# GAME: 9.728021667983297
# TOOLS: 8.46405597562352
# BUSINESS: 4.593161042771697
# LIFESTYLE: 3.9047511567543167
# PRODUCTIVITY: 3.8934657487868187
# FINANCE: 3.7016138133393524
# MEDICAL: 3.498476469924388
# SPORTS: 3.3969077982169056
# PERSONALIZATION: 3.317909942444419
# COMMUNICATION: 3.2389120866719328
# HEALTH_AND_FITNESS: 3.080916375126961
# PHOTOGRAPHY: 2.9454914795169844
# NEWS_AND_MAGAZINES: 2.7987811759395105
# SOCIAL: 2.663356280329534
# TRAVEL_AND_LOCAL: 2.3360794492720913
# SHOPPING: 2.245796185532107
# BOOKS_AND_REFERENCE: 2.144227513824625
# DATING: 1.8620923146371742
# VIDEO_PLAYERS: 1.794379866832186
# MAPS_AND_NAVIGATION: 1.3993905879697552
# FOOD_AND_DRINK: 1.2413948764247829
# EDUCATION: 1.1623970206522967
# ENTERTAINMENT: 0.9592596772373322
# LIBRARIES_AND_DEMO: 0.9366888613023362
# AUTO_AND_VEHICLES: 0.9254034533348381
# HOUSE_AND_HOME: 0.8238347816273558
# WEATHER: 0.8012639656923597
# EVENTS: 0.7109807019523756
# PARENTING: 0.6545536621148855
# ART_AND_DESIGN: 0.6432682541473874
# COMICS: 0.6206974382123914
# BEAUTY: 0.5981266222773953

# %% [markdown]
# The landscape seems significantly different on Google Play: there are not that many apps designed for fun, and it seems that a good number of apps are designed for practical purposes (family, tools, business, lifestyle, productivity, etc.). However, if we investigate this further, we can see that the family category (which accounts for almost 19% of the apps) means mostly games for kids.
#
# Even so, practical apps seem to have a better representation on Google Play compared to App Store. This picture is also confirmed by the frequency table we see for the `Genres` column:

# %%
display_table('and', -4)
# Out:
# The frequency table for Android apps by GENRES share:
#
# Tools: 8.452770567656021
# Entertainment: 6.071549486513937
# Education: 5.349283376594064
# Business: 4.593161042771697
# Productivity: 3.8934657487868187
# Lifestyle: 3.8934657487868187
# Finance: 3.7016138133393524
# Medical: 3.498476469924388
# Sports: 3.464620246021894
# Personalization: 3.317909942444419
# Communication: 3.2389120866719328
# Action: 3.103487191061957
# Health & Fitness: 3.080916375126961
# Photography: 2.9454914795169844
# News & Magazines: 2.7987811759395105
# Social: 2.663356280329534
# Travel & Local: 2.3247940413045933
# Shopping: 2.245796185532107
# Books & Reference: 2.144227513824625
# Simulation: 2.0426588421171425
# Dating: 1.8620923146371742
# Arcade: 1.8508069066696762
# Video Players & Editors: 1.7718090508971898
# Casual: 1.760523642929692
# Maps & Navigation: 1.3993905879697552
# Food & Drink: 1.2413948764247829
# Puzzle: 1.1285407967498025
# Racing: 0.9931159011398263
# Role Playing: 0.9366888613023362
# Libraries & Demo: 0.9366888613023362
# Auto & Vehicles: 0.9254034533348381
# Strategy: 0.91411804536734
# House & Home: 0.8238347816273558
# Weather: 0.8012639656923597
# Events: 0.7109807019523756
# Adventure: 0.6771244780498815
# Comics: 0.6094120302448933
# Beauty: 0.5981266222773953
# Art & Design: 0.5981266222773953
# Parenting: 0.49655795056991314
# Card: 0.45141631869992105
# Casino: 0.42884550276492495
# Trivia: 0.4175600947974269
# Educational;Education: 0.3949892788624309
# Board: 0.38370387089493285
# Educational: 0.3724184629274348
# Education;Education: 0.33856223902494076
# Word: 0.25956438325245457
# Casual;Pretend Play: 0.23699356731745852
# Music: 0.20313734341496445
# Racing;Action & Adventure: 0.16928111951247038
# Puzzle;Brain Games: 0.16928111951247038
# Entertainment;Music & Video: 0.16928111951247038
# Casual;Brain Games: 0.13542489560997628
# Casual;Action & Adventure: 0.13542489560997628
# Arcade;Action & Adventure: 0.12413948764247829
# Action;Action & Adventure: 0.10156867170748222
# Educational;Pretend Play: 0.0902832637399842
# Simulation;Action & Adventure: 0.07899785577248618
# Parenting;Education: 0.07899785577248618
# Entertainment;Brain Games: 0.07899785577248618
# Board;Brain Games: 0.07899785577248618
# Parenting;Music & Video: 0.06771244780498814
# Educational;Brain Games: 0.06771244780498814
# Casual;Creativity: 0.06771244780498814
# Art & Design;Creativity: 0.06771244780498814
# Education;Pretend Play: 0.05642703983749013
# Role Playing;Pretend Play: 0.0451416318699921
# Education;Creativity: 0.0451416318699921
# Role Playing;Action & Adventure: 0.03385622390249407
# Puzzle;Action & Adventure: 0.03385622390249407
# Entertainment;Creativity: 0.03385622390249407
# Entertainment;Action & Adventure: 0.03385622390249407
# Educational;Creativity: 0.03385622390249407
# Educational;Action & Adventure: 0.03385622390249407
# Education;Music & Video: 0.03385622390249407
# Education;Brain Games: 0.03385622390249407
# Education;Action & Adventure: 0.03385622390249407
# Adventure;Action & Adventure: 0.03385622390249407
# Video Players & Editors;Music & Video: 0.02257081593499605
# Sports;Action & Adventure: 0.02257081593499605
# Simulation;Pretend Play: 0.02257081593499605
# Puzzle;Creativity: 0.02257081593499605
# Music;Music & Video: 0.02257081593499605
# Entertainment;Pretend Play: 0.02257081593499605
# Casual;Education: 0.02257081593499605
# Board;Action & Adventure: 0.02257081593499605
# Video Players & Editors;Creativity: 0.011285407967498025
# Trivia;Education: 0.011285407967498025
# Travel & Local;Action & Adventure: 0.011285407967498025
# Tools;Education: 0.011285407967498025
# Strategy;Education: 0.011285407967498025
# Strategy;Creativity: 0.011285407967498025
# Strategy;Action & Adventure: 0.011285407967498025
# Simulation;Education: 0.011285407967498025
# Role Playing;Brain Games: 0.011285407967498025
# Racing;Pretend Play: 0.011285407967498025
# Puzzle;Education: 0.011285407967498025
# Parenting;Brain Games: 0.011285407967498025
# Music & Audio;Music & Video: 0.011285407967498025
# Lifestyle;Pretend Play: 0.011285407967498025
# Lifestyle;Education: 0.011285407967498025
# Health & Fitness;Education: 0.011285407967498025
# Health & Fitness;Action & Adventure: 0.011285407967498025
# Entertainment;Education: 0.011285407967498025
# Communication;Creativity: 0.011285407967498025
# Comics;Creativity: 0.011285407967498025
# Casual;Music & Video: 0.011285407967498025
# Card;Action & Adventure: 0.011285407967498025
# Books & Reference;Education: 0.011285407967498025
# Art & Design;Pretend Play: 0.011285407967498025
# Art & Design;Action & Adventure: 0.011285407967498025
# Arcade;Pretend Play: 0.011285407967498025
# Adventure;Education: 0.011285407967498025

# %% [markdown]
# The difference between the `Genres` and the `Category` columns is not crystal clear, but one thing we can notice is that the `Genres` column is much more granular (it has more categories). We're only looking for the bigger picture at the moment, so we'll only work with the `Category` column moving forward.
#
# Up to this point, we found that the App Store is dominated by apps designed for fun, while Google Play shows a more balanced landscape of both practical and for-fun apps. Now we'd like to get an idea about the kind of apps that have most users.
#
# ## Most Popular Apps by Genre on the App Store
#
# One way to find out what genres are the most popular (have the most users) is to calculate the average number of installs for each app genre. For the Google Play data set, we can find this information in the `Installs` column, but for the App Store data set this information is missing. As a workaround, we'll take the total number of user ratings as a proxy, which we can find in the `rating_count_tot` app.
#
# Below, we calculate the average number of user ratings per app genre on the App Store:

# %%
genres_ios = freq_table('ios', -5)

for genre in genres_ios:
	total = 0
	len_genre = 0

	for app in PLATFORM[1]['data_final']:
		genre_app = app[-5]
		if genre_app == genre:
			n_ratings = float(app[5])
			total += n_ratings
			len_genre += 1
	
	avg_n_ratings = total / len_genre
	print(genre, ':', avg_n_ratings)
# Out:
# Social Networking : 71548.34905660378
# Photo & Video : 28441.54375
# Games : 22812.92467948718
# Music : 57326.530303030304
# Reference : 74942.11111111111
# Health & Fitness : 23298.015384615384
# Weather : 52279.892857142855
# Utilities : 18684.456790123455
# Travel : 28243.8
# Shopping : 26919.690476190477
# News : 21248.023255813954
# Navigation : 86090.33333333333
# Lifestyle : 16485.764705882353
# Entertainment : 14029.830708661417
# Food & Drink : 33333.92307692308
# Sports : 23008.898550724636
# Book : 39758.5
# Finance : 31467.944444444445
# Education : 7003.983050847458
# Productivity : 21028.410714285714
# Business : 7491.117647058823
# Catalogs : 4004.0
# Medical : 612.0

# %% [markdown]
# On average, navigation apps have the highest number of user reviews, but this figure is heavily influenced by Waze and Google Maps, which have close to half a million user reviews together:

# %%
for app in PLATFORM[1]['data_final']:
	if app[-5] == 'Navigation':
		print(app[1], ':', app[5]) # Print name and number of ratings
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Google Maps - Navigation & Transit : 154911
# Geocaching® : 12811
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5

# %% [markdown]
# The same pattern applies to social networking apps, where the average number is heavily influenced by a few giants like Facebook, Pinterest, Skype, etc. Same applies to music apps, where a few big players like Pandora, Spotify, and Shazam heavily influence the average number.
#
# Our aim is to find popular genres, but navigation, social networking or music apps might seem more popular than they really are. The average number of ratings seem to be skewed by very few apps which have hundreds of thousands of user ratings, while the other apps may struggle to get past the 10,000 threshold. We could get a better picture by removing these extremely popular apps for each genre and then rework the averages, but we'll leave this level of detail for later.
#
# Reference apps have 74,942 user ratings on average, but it's actually the Bible and Dictionary.com which skew up the average rating:

# %%
for app in PLATFORM[1]['data_final']:
	if app[-5] == 'Reference':
		print(app[1], ':', app[5])  # Print name and number of ratings
# Out:
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Google Translate : 26786
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# Merriam-Webster Dictionary : 16849
# Night Sky : 12122
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# WWDC : 762
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# VPN Express : 14
# Real Bike Traffic Rider Virtual Reality Glasses : 8
# 教えて!goo : 0
# Jishokun-Japanese English Dictionary & Translator : 0

# %% [markdown]
# However, this niche seems to show some potential. One thing we could do is take another popular book and turn it into an app where we could add different features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes about the book, etc. On top of that, we could also embed a dictionary within the app, so users don't need to exit our app to look up words in an external app.
#
# This idea seems to fit well with the fact that the App Store is dominated by for-fun apps. This suggests the market might be a bit saturated with for-fun apps, which means a practical app might have more of a chance to stand out among the huge number of apps on the App Store.
#
# Other genres that seem popular include weather, book, food and drink, or finance. The book genre seem to overlap a bit with the app idea we described above, but the other genres don't seem too interesting to us:
#
# - Weather apps — people generally don't spend too much time in-app, and the chances of making profit from in-app adds are low. Also, getting reliable live weather data may require us to connect our apps to non-free APIs.
#
# - Food and drink — examples here include Starbucks, Dunkin' Donuts, McDonald's, etc. So making a popular food and drink app requires actual cooking and a delivery service, which is outside the scope of our company.
#
# - Finance apps — these apps involve banking, paying bills, money transfer, etc. Building a finance app requires domain knowledge, and we don't want to hire a finance expert just to build an app.
#
# Now let's analyze the Google Play market a bit.
#
# ## Most Popular Apps by Genre on Google Play
#
# For the Google Play market, we actually have data about the number of installs, so we should be able to get a clearer picture about genre popularity. However, the install numbers don't seem precise enough — we can see that most values are open-ended (100+, 1,000+, 5,000+, etc.):

# %%
display_table('and', 5) # the Installs columns
# Out:
# The frequency table for Android apps by INSTALLS share:
#
# 1,000,000+: 15.731858706692247
# 100,000+: 11.556257758717978
# 10,000,000+: 10.551856449610653
# 10,000+: 10.202008802618215
# 1,000+: 8.396343527818532
# 100+: 6.906669676108791
# 5,000,000+: 6.827671820336305
# 500,000+: 5.563706127976526
# 50,000+: 4.773727570251665
# 5,000+: 4.51416318699921
# 10+: 3.532332693826882
# 500+: 3.250197494639431
# 50,000,000+: 2.302223225369597
# 100,000,000+: 2.1329421058571265
# 50+: 1.9072339465071662
# 5+: 0.7899785577248618
# 1+: 0.5078433585374111
# 500,000,000+: 0.27084979121995256
# 1,000,000,000+: 0.22570815934996052
# 0+: 0.0451416318699921
# 0: 0.011285407967498025

# %% [markdown]
# One problem with this data is that is not precise. For instance, we don't know whether an app with 100,000+ installs has 100,000 installs, 200,000, or 350,000. However, we don't need very precise data for our purposes — we only want to get an idea which app genres attract the most users, and we don't need perfect precision with respect to the number of users.
#
# We're going to leave the numbers as they are, which means that we'll consider that an app with 100,000+ installs has 100,000 installs, and an app with 1,000,000+ installs has 1,000,000 installs, and so on.
#
# To perform computations, however, we'll need to convert each install number to `float` — this means that we need to remove the commas and the plus characters, otherwise the conversion will fail and raise an error. We'll do this directly in the loop below, where we also compute the average number of installs for each genre (category).

# %%
categories_android = freq_table('and', 1)

for category in categories_android:
	total = 0
	len_category = 0

	for app in PLATFORM[0]['data_final']:
		category_app = app[1]
		if category_app == category:
			n_installs = app[5]
			n_installs = n_installs.replace(',', '')
			n_installs = n_installs.replace('+', '')
			total += float(n_installs)
			len_category += 1

	avg_n_installs = total / len_category
	print(category, ':', avg_n_installs)
# Out:
# ART_AND_DESIGN : 1986335.0877192982
# AUTO_AND_VEHICLES : 647317.8170731707
# BEAUTY : 513151.88679245283
# BOOKS_AND_REFERENCE : 8767811.894736841
# BUSINESS : 1712290.1474201474
# COMICS : 817657.2727272727
# COMMUNICATION : 38456119.167247385
# DATING : 854028.8303030303
# EDUCATION : 1833495.145631068
# ENTERTAINMENT : 11640705.88235294
# EVENTS : 253542.22222222222
# FINANCE : 1387692.475609756
# FOOD_AND_DRINK : 1924897.7363636363
# HEALTH_AND_FITNESS : 4188821.9853479853
# HOUSE_AND_HOME : 1331540.5616438356
# LIBRARIES_AND_DEMO : 638503.734939759
# LIFESTYLE : 1437816.2687861272
# GAME : 15588015.603248259
# FAMILY : 3695641.8198090694
# MEDICAL : 121716.72258064516
# SOCIAL : 23253652.127118643
# SHOPPING : 7036877.311557789
# PHOTOGRAPHY : 17840110.40229885
# SPORTS : 3638640.1428571427
# TRAVEL_AND_LOCAL : 13984077.710144928
# TOOLS : 10801391.298666667
# PERSONALIZATION : 5201482.6122448975
# PRODUCTIVITY : 16787331.344927534
# PARENTING : 542603.6206896552
# WEATHER : 5074486.197183099
# VIDEO_PLAYERS : 24727872.452830188
# NEWS_AND_MAGAZINES : 9549178.467741935
# MAPS_AND_NAVIGATION : 4056941.7741935486

# %% [markdown]
# On average, communication apps have the most installs: 38,456,119. This number is heavily skewed up by a few apps that have over one billion installs (WhatsApp, Facebook Messenger, Skype, Google Chrome, Gmail, and Hangouts), and a few others with over 100 and 500 million installs:

# %%
for app in PLATFORM[0]['data_final']:
	if app[1] == 'COMMUNICATION' and (app[5] == '1,000,000,000+' or app[5] == '500,000,000+' or app[5] == '100,000,000+'):
		print(app[0], ':', app[5])
# Out:
# WhatsApp Messenger : 1,000,000,000+
# imo beta free calls and text : 100,000,000+
# Android Messages : 100,000,000+
# Google Duo - High Quality Video Calls : 500,000,000+
# Messenger – Text and Video Chat for Free : 1,000,000,000+
# imo free video calls and chat : 500,000,000+
# Skype - free IM & video calls : 1,000,000,000+
# Who : 100,000,000+
# GO SMS Pro - Messenger, Free Themes, Emoji : 100,000,000+
# LINE: Free Calls & Messages : 500,000,000+
# Google Chrome: Fast & Secure : 1,000,000,000+
# Firefox Browser fast & private : 100,000,000+
# UC Browser - Fast Download Private & Secure : 500,000,000+
# Gmail : 1,000,000,000+
# Hangouts : 1,000,000,000+
# Messenger Lite: Free Calls & Messages : 100,000,000+
# Kik : 100,000,000+
# KakaoTalk: Free Calls & Text : 100,000,000+
# Opera Mini - fast web browser : 100,000,000+
# Opera Browser: Fast and Secure : 100,000,000+
# Telegram : 100,000,000+
# Truecaller: Caller ID, SMS spam blocking & Dialer : 100,000,000+
# UC Browser Mini -Tiny Fast Private & Secure : 100,000,000+
# Viber Messenger : 500,000,000+
# WeChat : 100,000,000+
# Yahoo Mail – Stay Organized : 100,000,000+
# BBM - Free Calls & Messages : 100,000,000+

# %% [markdown]
# If we removed all the communication apps that have over 100 million installs, the average would be reduced roughly ten times:

# %%
under_100_m = []

for app in PLATFORM[0]['data_final']:
	n_installs = app[5]
	n_installs = n_installs.replace(',', '')
	n_installs = n_installs.replace('+', '')

	if (app[1] == 'COMMUNICATION') and (float(n_installs) < 100_000_000):
		under_100_m.append(float(n_installs))

sum(under_100_m) / len(under_100_m)
# Out:
# 3603485.3884615386

# %% [markdown]
# We see the same pattern for the video players category, which is the runner-up with 24,727,872 installs. The market is dominated by apps like Youtube, Google Play Movies & TV, or MX Player. The pattern is repeated for social apps (where we have giants like Facebook, Instagram, Google+, etc.), photography apps (Google Photos and other popular photo editors), or productivity apps (Microsoft Word, Dropbox, Google Calendar, Evernote, etc.).
#
# Again, the main concern is that these app genres might seem more popular than they really are. Moreover, these niches seem to be dominated by a few giants who are hard to compete against.
#
# The game genre seems pretty popular, but previously we found out this part of the market seems a bit saturated, so we'd like to come up with a different app recommendation if possible.
#
# The books and reference genre looks fairly popular as well, with an average number of installs of 8,767,811. It's interesting to explore this in more depth, since we found this genre has some potential to work well on the App Store, and our aim is to recommend an app genre that shows potential for being profitable on both the App Store and Google Play.
#
# Let's take a look at some of the apps from this genre and their number of installs:

# %%
for app in PLATFORM[0]['data_final']:
	if app[1] == 'BOOKS_AND_REFERENCE':
		print(app[0], ':', app[5])
# Out:
# E-Book Read - Read Book for free : 50,000+
# Download free book with green book : 100,000+
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Free Panda Radio Music : 100,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# English Grammar Complete Handbook : 500,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# Google Play Books : 1,000,000,000+
# AlReader -any text book reader : 5,000,000+
# Offline English Dictionary : 100,000+
# Offline: English to Tagalog Dictionary : 500,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# Recipes of Prophetic Medicine for free : 500,000+
# ReadEra – free ebook reader : 1,000,000+
# Anonymous caller detection : 10,000+
# Ebook Reader : 5,000,000+
# Litnet - E-books : 100,000+
# Read books online : 5,000,000+
# English to Urdu Dictionary : 500,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# English Persian Dictionary : 500,000+
# Flybook : 500,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# English translation from Bengali : 100,000+
# Pdf Book Download - Read Pdf Book : 100,000+
# Free Book Reader : 100,000+
# eBoox new: Reader for fb2 epub zip books : 50,000+
# Only 30 days in English, the guideline is guaranteed : 500,000+
# Moon+ Reader : 10,000,000+
# SH-02J Owner's Manual (Android 8.0) : 50,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Azpen eReader : 500,000+
# URBANO V 02 instruction manual : 100,000+
# Bible : 100,000,000+
# C Programs and Reference : 50,000+
# C Offline Tutorial : 1,000+
# C Programs Handbook : 50,000+
# Amazon Kindle : 100,000,000+
# Aab e Hayat Full Novel : 100,000+
# Aldiko Book Reader : 10,000,000+
# Google I/O 2018 : 500,000+
# R Language Reference Guide : 10,000+
# Learn R Programming Full : 5,000+
# R Programing Offline Tutorial : 1,000+
# Guide for R Programming : 5+
# Learn R Programming : 10+
# R Quick Reference Big Data : 1,000+
# V Made : 100,000+
# Wattpad 📖 Free Books : 100,000,000+
# Dictionary - WordWeb : 5,000,000+
# Guide (for X-MEN) : 100,000+
# AC Air condition Troubleshoot,Repair,Maintenance : 5,000+
# AE Bulletins : 1,000+
# Ae Allah na Dai (Rasa) : 10,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Ag PhD Field Guide : 10,000+
# Ag PhD Deficiencies : 10,000+
# Ag PhD Planting Population Calculator : 1,000+
# Ag PhD Soybean Diseases : 1,000+
# Fertilizer Removal By Crop : 50,000+
# A-J Media Vault : 50+
# Al-Quran (Free) : 10,000,000+
# Al Quran (Tafsir & by Word) : 500,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al-Muhaffiz : 50,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Al-Quran 30 Juz free copies : 500,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Surah Al-Waqiah : 100,000+
# Hisnul Al Muslim - Hisn Invocations & Adhkaar : 100,000+
# Satellite AR : 1,000,000+
# Audiobooks from Audible : 100,000,000+
# Kinot & Eichah for Tisha B'Av : 10,000+
# AW Tozer Devotionals - Daily : 5,000+
# Tozer Devotional -Series 1 : 1,000+
# The Pursuit of God : 1,000+
# AY Sing : 5,000+
# Ay Hasnain k Nana Milad Naat : 10,000+
# Ay Mohabbat Teri Khatir Novel : 10,000+
# Arizona Statutes, ARS (AZ Law) : 1,000+
# Oxford A-Z of English Usage : 1,000,000+
# BD Fishpedia : 1,000+
# BD All Sim Offer : 10,000+
# Youboox - Livres, BD et magazines : 500,000+
# B&H Kids AR : 10,000+
# B y H Niños ES : 5,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# Borneo Bible, BM Bible : 10,000+
# MOD Black for BM : 100+
# BM Box : 1,000+
# Anime Mod for BM : 100+
# NOOK: Read eBooks & Magazines : 10,000,000+
# NOOK Audiobooks : 500,000+
# NOOK App for NOOK Devices : 500,000+
# Browsery by Barnes & Noble : 5,000+
# bp e-store : 1,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# BR Ambedkar Biography & Quotes : 10,000+
# BU Alsace : 100+
# Catholic La Bu Zo Kam : 500+
# Khrifa Hla Bu (Solfa) : 10+
# Kristian Hla Bu : 10,000+
# SA HLA BU : 1,000+
# Learn SAP BW : 500+
# Learn SAP BW on HANA : 500+
# CA Laws 2018 (California Laws and Codes) : 5,000+
# Bootable Methods(USB-CD-DVD) : 10,000+
# cloudLibrary : 100,000+
# SDA Collegiate Quarterly : 500+
# Sabbath School : 100,000+
# Cypress College Library : 100+
# Stats Royale for Clash Royale : 1,000,000+
# GATE 21 years CS Papers(2011-2018 Solved) : 50+
# Learn CT Scan Of Head : 5,000+
# Easy Cv maker 2018 : 10,000+
# How to Write CV : 100,000+
# CW Nuclear : 1,000+
# CY Spray nozzle : 10+
# BibleRead En Cy Zh Yue : 5+
# CZ-Help : 5+
# Modlitební knížka CZ : 500+
# Guide for DB Xenoverse : 10,000+
# Guide for DB Xenoverse 2 : 10,000+
# Guide for IMS DB : 10+
# DC HSEMA : 5,000+
# DC Public Library : 1,000+
# Painting Lulu DC Super Friends : 1,000+
# Dictionary : 10,000,000+
# Fix Error Google Playstore : 1,000+
# D. H. Lawrence Poems FREE : 1,000+
# Bilingual Dictionary Audio App : 5,000+
# DM Screen : 10,000+
# wikiHow: how to do anything : 1,000,000+
# Dr. Doug's Tips : 1,000+
# Bible du Semeur-BDS (French) : 50,000+
# La citadelle du musulman : 50,000+
# DV 2019 Entry Guide : 10,000+
# DV 2019 - EDV Photo & Form : 50,000+
# DV 2018 Winners Guide : 1,000+
# EB Annual Meetings : 1,000+
# EC - AP & Telangana : 5,000+
# TN Patta Citta & EC : 10,000+
# AP Stamps and Registration : 10,000+
# CompactiMa EC pH Calibration : 100+
# EGW Writings 2 : 100,000+
# EGW Writings : 1,000,000+
# Bible with EGW Comments : 100,000+
# My Little Pony AR Guide : 1,000,000+
# SDA Sabbath School Quarterly : 500,000+
# Duaa Ek Ibaadat : 5,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+
# EP Research Service : 1,000+
# Hymnes et Louanges : 100,000+
# EU Charter : 1,000+
# EU Data Protection : 1,000+
# EU IP Codes : 100+
# EW PDF : 5+
# BakaReader EX : 100,000+
# EZ Quran : 50,000+
# FA Part 1 & 2 Past Papers Solved Free – Offline : 5,000+
# La Fe de Jesus : 1,000+
# La Fe de Jesús : 500+
# Le Fe de Jesus : 500+
# Florida - Pocket Brainbook : 1,000+
# Florida Statutes (FL Code) : 1,000+
# English To Shona Dictionary : 10,000+
# Greek Bible FP (Audio) : 1,000+
# Golden Dictionary (FR-AR) : 500,000+
# Fanfic-FR : 5,000+
# Bulgarian French Dictionary Fr : 10,000+
# Chemin (fr) : 1,000+
# The SCP Foundation DB fr nn5n : 1,000+

# %% [markdown]
# The book and reference genre includes a variety of apps: software for processing and reading ebooks, various collections of libraries, dictionaries, tutorials on programming or languages, etc. It seems there's still a small number of extremely popular apps that skew the average:

# %%
for app in PLATFORM[0]['data_final']:
	if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000,000+' or app[5] == '500,000,000+' or app[5] == '100,000,000+'):
		print(app[0], ':', app[5])
# Out:
# Google Play Books : 1,000,000,000+
# Bible : 100,000,000+
# Amazon Kindle : 100,000,000+
# Wattpad 📖 Free Books : 100,000,000+
# Audiobooks from Audible : 100,000,000+

# %% [markdown]
# However, it looks like there are only a few very popular apps, so this market still shows potential. Let's try to get some app ideas based on the kind of apps that are somewhere in the middle in terms of popularity (between 1,000,000 and 100,000,000 downloads):

# %%
for app in PLATFORM[0]['data_final']:
	if app[1] == 'BOOKS_AND_REFERENCE' and (app[5] == '1,000,000+' or app[5] == '5,000,000+' or app[5] == '10,000,000+' or app[5] == '50,000,000+'):
		print(app[0], ':', app[5])
# Out:
# Wikipedia : 10,000,000+
# Cool Reader : 10,000,000+
# Book store : 1,000,000+
# FBReader: Favorite Book Reader : 10,000,000+
# Free Books - Spirit Fanfiction and Stories : 1,000,000+
# AlReader -any text book reader : 5,000,000+
# FamilySearch Tree : 1,000,000+
# Cloud of Books : 1,000,000+
# ReadEra – free ebook reader : 1,000,000+
# Ebook Reader : 5,000,000+
# Read books online : 5,000,000+
# eBoox: book reader fb2 epub zip : 1,000,000+
# All Maths Formulas : 1,000,000+
# Ancestry : 5,000,000+
# HTC Help : 10,000,000+
# Moon+ Reader : 10,000,000+
# English-Myanmar Dictionary : 1,000,000+
# Golden Dictionary (EN-AR) : 1,000,000+
# All Language Translator Free : 1,000,000+
# Aldiko Book Reader : 10,000,000+
# Dictionary - WordWeb : 5,000,000+
# 50000 Free eBooks & Free AudioBooks : 5,000,000+
# Al-Quran (Free) : 10,000,000+
# Al Quran Indonesia : 10,000,000+
# Al'Quran Bahasa Indonesia : 10,000,000+
# Al Quran Al karim : 1,000,000+
# Al Quran : EAlim - Translations & MP3 Offline : 5,000,000+
# Koran Read &MP3 30 Juz Offline : 1,000,000+
# Hafizi Quran 15 lines per page : 1,000,000+
# Quran for Android : 10,000,000+
# Satellite AR : 1,000,000+
# Oxford A-Z of English Usage : 1,000,000+
# Dictionary.com: Find Definitions for English Words : 10,000,000+
# English Dictionary - Offline : 10,000,000+
# Bible KJV : 5,000,000+
# NOOK: Read eBooks & Magazines : 10,000,000+
# Brilliant Quotes: Life, Love, Family & Motivation : 1,000,000+
# Stats Royale for Clash Royale : 1,000,000+
# Dictionary : 10,000,000+
# wikiHow: how to do anything : 1,000,000+
# EGW Writings : 1,000,000+
# My Little Pony AR Guide : 1,000,000+
# Spanish English Translator : 10,000,000+
# Dictionary - Merriam-Webster : 10,000,000+
# JW Library : 10,000,000+
# Oxford Dictionary of English : Free : 10,000,000+
# English Hindi Dictionary : 10,000,000+
# English to Hindi Dictionary : 5,000,000+

# %% [markdown]
# This niche seems to be dominated by software for processing and reading ebooks, as well as various collections of libraries and dictionaries, so it's probably not a good idea to build similar apps since there'll be some significant competition.
#
# We also notice there are quite a few apps built around the book Quran, which suggests that building an app around a popular book can be profitable. It seems that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets.
#
# However, it looks like the market is already full of libraries, so we need to add some special features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.
#
# ## Conclusions
#
# In this project, we analyzed data about the App Store and Google Play mobile apps with the goal of recommending an app profile that can be profitable for both markets.
#
# We concluded that taking a popular book (perhaps a more recent book) and turning it into an app could be profitable for both the Google Play and the App Store markets. The markets are already full of libraries, so we need to add some special features besides the raw version of the book. This might include daily quotes from the book, an audio version of the book, quizzes on the book, a forum where people can discuss the book, etc.
